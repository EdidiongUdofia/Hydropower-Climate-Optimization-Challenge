# %% [markdown]
# ## IBM SkillsBuild Hydropower Climate Optimisation Challenge

# %% [markdown]
# #### **1.0 Introduction**:

# %% [markdown]
# In the remote Kalam region of Pakistan, micro-hydropower plants (MHPs) are the backbone of energy generation for rural communities. But nature doesn’t always play along. Water flow fluctuates, maintenance disrupts supply, and the weather throws in its own surprises. From rainfall to temperature shifts, climate conditions impact how much energy is available—and how much is needed.
#
# In this challenge, your task is to build a model that accurately predicts energy load generation (in kWh), drawing on MHP data like voltage, current, power factors, and energy metrics, combined with climate indicators like temperature, dew point, wind speed, and precipitation. The goal is to uncover patterns and insights that can improve forecasting, optimise energy distribution, and enhance system reliability.
#
# Predicting energy needs means less waste, fewer blackouts, and smarter resource management—all crucial for keeping the lights on in off-grid communities. Understanding how climate affects energy demand, and what that means for sustainable power planning, is a critical insight for sustainable power projects all over the world.
#
# The data was curated by the Center for Intelligent Systems and Networks Research (CISNR), University of Engineering and Technology Peshawar.
#
# This challenge is sponsored and supported by IBM SkillsBuild, who have made a number of courses and digital credentials available through the IBM SkillsBuild platform.

# %% [markdown]
# *This solution tackles the IBM SkillsBuild Hydropower Climate Optimization Challenge, which focuses on predicting daily energy consumption for different consumer devices in Kalam, Pakistan. The solution leverages comprehensive feature engineering, temporal data segmentation, and advanced ensemble modeling to achieve accurate predictions despite the region's challenging seasonal patterns and extreme weather conditions.*

# %% [markdown]
# **Objectives:**
# 1. Predict daily energy consumption (kWh) for various consumer devices in Kalam
# 2. Capture seasonal and weather-dependent energy usage patterns
# 3. Handle offline periods and missing data appropriately
# 4. Create a robust model that generalizes well across different devices and time periods

# %% [markdown]
# ### ETL Process

# %% [markdown]
# ## Extract
#
# *****Data Sources:*****
# - ***Primary dataset***: Consumer energy consumption at 5-minute intervals
# - ***Climate data***: Temperature, precipitation, wind components, and snowfall measurements
# - ***Sample submission file***: Used to determine test set devices and prediction format
#
# *****Data Formats:*****: Electrical data (CSV file), Climate data (Excel file)
#
# *****Considerations:*****: Device filtering to exclude devices and users not present in the test set

# %% [markdown]
# ## Transform
#
# 1. **Data Cleaning**:
#    - Conversion of timestamps to datetime objects
#    - Identification and exclusion of specific devices not in test set
#    - Filtering to keep only users present in the test set
#
# 2. **Aggregation**:
#    - Aggregation of 5-minute data to daily totals with multiple statistical metrics
#    - Comprehensive metrics for voltage, current, and power factor (mean, std, min, max)
#
# 3. **Online/Offline Classification**:
#    - Identification of entire weeks where consumption was zero across all days
#    - Classification of days into "online" and "offline" based on weekly patterns
#    - Focus on "online" days to improve signal quality
#
# 4. **Feature Engineering**:
#    - Extraction of consumer device and user IDs from source strings
#    - Creation of temporal features and cyclical encodings
#    - Integration of climate data with multiple temperature metrics
#    - Special features for Pakistan holidays and Ramadan periods
#    - Advanced temperature trend features (acceleration, volatility, extremes)

# %% [markdown]
# ## Load
#
# - Intermediate data saved as CSV files for further processing:
#   - `offline_days_enriched.csv`: Days with zero power consumption (entire week)
#   - `filtered_online_days_enriched.csv`: Final filtered dataset with only relevant users of days with normal power consumption
#
# ## Data Modeling
#
# ### Strategic Data Segmentation
#
# The data was strategically divided into four segments to capture different seasonal patterns:
#
# 1. **Data1**: August–September 2024 and October 2023 (late summer/early fall)
# 2. **Data2**: November–December 2023 and July 2024 (winter and mid-summer)
# 3. **Data3**: All other periods with distinct consumption patterns
# 4. **Data4**: Complete dataset for a global model
#
# ### Model Configurations
#
# Seven different LightGBM configurations were trained for each data segment:
#
# 1. **Precise**: Conservative approach with deep trees (`max_depth=8`, `learning_rate=0.01`)
# 2. **Feature Selective**: Aggressive feature selection (`colsample_bytree=0.6`, `feature_fraction=0.7`)
# 3. **Robust**: Focus on outlier resistance (`min_data_in_leaf=20`, `reg_alpha=0.5`)
# 4. **Deep Forest**: Very deep trees with many estimators (`max_depth=12`, `n_estimators=3000`)
# 5. **Highly Regularized**: Strong regularization (`reg_alpha=2.0, reg_lambda=2.0`)
# 6. **Fast Learner:**: High learning rate for quick convergence (`learning_rate=0.08`)
# 7. **Balanced:**: Optimized for bias-variance tradeoff (`max_depth=7, bagging_freq=5`)

# %% [markdown]
# ## Optimization Approach
#
# - **Cross-Validation**: 5-fold cross-validation for robust model evaluation
# - **Bayesian Optimization**: Used to find optimal weights for combining base models
# - **Feature Importance Analysis**: Identified and leveraged the most predictive features
# - **Performance Monitoring**: Tracked RMSE across both individual models and ensembles
#
# ## Data Loading and Initial Exploration
#
# In this section, we load the main datasets and perform initial exploration:
#
# 1. Main consumption data (5-minute intervals)
# 2. Sample submission file to understand the prediction format
# 3. Climate data with meteorological measurements
#
# We also apply initial filtering to focus only on devices present in the test set.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
# <a href=#one>1. Introduction</a>
#
# <a href=#two>2. Importing Packages & Loading the Data</a>
#
# <a href=#three>3. Data Overview & Data Cleaning</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Exploratory Data Analysis (EDA)</a>
#
# <a href=#six>6. Modeling</a>
#
# <a href=#seven>7. Model Performance</a>
#
# <a href=#nine>8. Conclusion</a>

# %% [markdown]
#  <a id="two"></a>
# ## 2. Importing Packages & Loading the Data
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages & Loading the Data⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. Furthermore, we will load the data from the `df_train` file, as well as the `df_test` file, into a DataFrame. |
#
# ---

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from plotly->catboost) (8.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\eudofia\appdata\local\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
# Libraries for data loading, data manipulation and data visulisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

import zipfile
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import time
import logging
import os
import gc
import json
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold, train_test_split
from bayes_opt import BayesianOptimization
import random

def seed_everything(seed: int = 42):
    """
    Set random seed for reproducibility in Python and NumPy.
    
    Args:
        seed (int): The seed value (default: 42)
    """
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything()


# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Create output folder
os.makedirs('output', exist_ok=True)


# Libraries that helps with statistical methods and visualizations
from  scipy import stats
from scipy.stats import norm
from scipy.stats import pearsonr
from statsmodels.formula.api import ols
import statsmodels.formula.api as sm
from statsmodels.stats.outliers_influence import OLSInfluence as influence
from sklearn.tree import plot_tree

import gc
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Libraries for data preparation and model building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from mpl_toolkits.mplot3d import Axes3D
import math
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVR
import catboost as cb 
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import StackingRegressor
import pickle

# Setting global constants to ensure notebook results are reproducible
TRAIN_TEST_VAR = 0.2 #Variable indicating the ratio of Training to Testing data when splitting datasets for validation
RAND_STATE = 42 #Variable used to determine random state of methods in order to replicate model training results

# %% [markdown]
# **Python environment:**
#
# - catboost==1.2.2
# - pandas-dq==1.28
# - pandas-profiling==3.6.6
# - pep8==1.7.1
# - scikit-learn-intelex==2021.20221004.171935
# - scipy==1.9.1
# - statsmodels==0.13.2
# - xgboost==2.0.0

# %% [markdown]
# #### **Loading the Data**:

# %%
logger.info("Loading data...")
start_time = time.time()

energy_df = pd.read_csv('Data.csv')
logger.info(f"✓ Main data loaded: {len(energy_df):,} records")
# Out:
# 2025-06-05 11:43:37,038 - INFO - Loading data...
# 2025-06-05 11:44:38,866 - INFO - ✓ Main data loaded: 39,147,559 records

# %%
# Display sample data
display(energy_df.head())
# Out:
#              date_time   v_red  current  power_factor       kwh  \
# 0  2024-07-22 18:20:00  137.65     0.08          0.72  0.000661
# 1  2024-07-22 18:25:00  122.82     0.08          0.73  0.000598
# 2  2024-07-22 18:30:00  119.70     0.08          0.74  0.000591
# 3  2024-07-22 18:35:00  124.53     0.08          0.75  0.000623
# 4  2024-07-22 18:40:00  134.84     0.08          0.74  0.000665
#
#                            Source  v_blue  v_yellow  consumer_device_9  \
# 0  consumer_device_10_data_user_1     NaN       NaN                  0
# 1  consumer_device_10_data_user_1     NaN       NaN                  0
# 2  consumer_device_10_data_user_1     NaN       NaN                  0
# 3  consumer_device_10_data_user_1     NaN       NaN                  0
# 4  consumer_device_10_data_user_1     NaN       NaN                  0
#
#    consumer_device_x
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                 10

# %%
# Extracting device ID for filtering
energy_df['device_id'] = energy_df['Source'].str.extract(r'consumer_device_(\d+)').astype(int)

# Filter devices to exclude (devices not present in test set)
DEVICES_TO_DROP = set([3, 5, 11, 14, 15, 17, 24, 25, 27, 33, 4, 9])
original_count = len(energy_df)
energy_df = energy_df[~energy_df['device_id'].isin(DEVICES_TO_DROP)]
logger.info(f"Device filtering: {original_count - len(energy_df)} records removed")

# Remove device_id column which is no longer needed
energy_df = energy_df.drop(columns=['device_id'])
# Out:
# 2025-06-05 11:50:48,733 - INFO - Device filtering: 15194237 records removed

# %%
# Loading Sample Submission File
ss = pd.read_csv('SampleSubmission.csv')
logger.info(f"✓ Sample submission loaded: {len(ss):,} records")
display(ss.head())

# Loading Climate Data
climate_df = pd.read_excel('ClimateData.xlsx')
logger.info(f"✓ Climate data loaded: {len(climate_df):,} records")
display(climate_df.head())
# Out:
# 2025-06-05 11:53:10,340 - INFO - ✓ Sample submission loaded: 6,014 records
#                                           ID  kwh
# 0  2024-09-24_consumer_device_12_data_user_1    0
# 1  2024-09-25_consumer_device_12_data_user_1    0
# 2  2024-09-26_consumer_device_12_data_user_1    0
# 3  2024-09-27_consumer_device_12_data_user_1    0
# 4  2024-09-28_consumer_device_12_data_user_1    0
# 2025-06-05 11:53:14,352 - INFO - ✓ Climate data loaded: 12,228 records
#             Date Time  Temperature (°C)  Dewpoint Temperature (°C)  \
# 0 2023-06-03 13:00:00          7.199731                  -2.448126
# 1 2023-06-03 14:00:00          6.000620                  -2.597540
# 2 2023-06-03 15:00:00          4.789972                  -2.696951
# 3 2023-06-03 16:00:00          3.158746                  -2.879324
# 4 2023-06-03 17:00:00          1.671426                  -3.255606
#
#    U Wind Component (m/s)  V Wind Component (m/s)  Total Precipitation (mm)  \
# 0               -0.034195                0.060989                  0.000377
# 1               -0.080688                0.018585                  0.000398
# 2                0.057449               -0.352020                  0.000418
# 3                0.051529               -0.608948                  0.000420
# 4                0.056137               -0.739838                  0.000420
#
#    Snowfall (mm)  Snow Cover (%)
# 0            0.0       99.972656
# 1            0.0       99.972656
# 2            0.0       99.972656
# 3            0.0       99.972656
# 4            0.0       99.972656

# %% [markdown]
# ## 3. Data Overview and Data Cleaning/Preprocessing/Aggregation

# %%
# Basic preprocessing
energy_df['date_time'] = pd.to_datetime(energy_df['date_time'])
energy_df['Date'] = pd.to_datetime(energy_df['date_time'].dt.date)
energy_df['Year'] = energy_df['date_time'].dt.year

# Extracting device/user information
energy_df[['consumer_device', 'data_user']] = energy_df['Source'].str.extract(r'(consumer_device_\d+)_data_user_(\d+)')

elapsed = time.time() - start_time
logger.info(f"Data loading completed in {elapsed:.2f} seconds")
# Out:
# 2025-06-05 11:59:17,972 - INFO - Data loading completed in 940.93 seconds

# %% [markdown]
# **Aggregation**

# %% [markdown]
# In this section, we:
#
# 1. Aggregate the 5-minute data to daily totals
# 2. Calculate statistical metrics for each electrical parameter
# 3. Identify and separate online/offline periods
# 4. Filter to include only users present in the test set

# %%
# Enriched Data Aggregation (5min → DAILY)

start_time = time.time()
logger.info("Enriched data aggregation (multiple metrics)...")

# Defining aggregations for electrical columns
daily_aggs = {
    'kwh': 'sum',
    'v_red': ['mean', 'std', 'min', 'max'],
    'v_blue': ['mean', 'std', 'min', 'max'],
    'v_yellow': ['mean', 'std', 'min', 'max'],
    'current': ['mean', 'std', 'min', 'max'],
    'power_factor': ['mean', 'min', 'max']
}

# Aggregation with multiple metrics
daily_data = energy_df.groupby(['Source', 'Date']).agg(daily_aggs)
daily_data.columns = ['_'.join(col).strip() for col in daily_data.columns.values]
daily_data = daily_data.reset_index()
logger.info(f"Enriched aggregated data: {len(daily_data)} records")

# Display sample of aggregated data
display(daily_data.head())
elapsed = time.time() - start_time
logger.info(f"ENRICHED DATA AGGREGATION completed in {elapsed:.2f} seconds")
# Out:
# 2025-06-05 12:04:21,640 - INFO - Enriched data aggregation (multiple metrics)...
# 2025-06-05 12:04:31,474 - INFO - Enriched aggregated data: 83492 records
#                            Source       Date   kwh_sum  v_red_mean  v_red_std  \
# 0  consumer_device_10_data_user_1 2024-07-22  0.024330   99.162941  35.429561
# 1  consumer_device_10_data_user_1 2024-07-23  0.103560  101.665556  59.016168
# 2  consumer_device_10_data_user_1 2024-07-24  0.137543  100.080938  67.120827
# 3  consumer_device_10_data_user_1 2024-07-25  0.121011  101.122604  59.350940
# 4  consumer_device_10_data_user_1 2024-07-26  0.000000   32.168472  52.802693
#
#    v_red_min  v_red_max  v_blue_mean  v_blue_std  v_blue_min  ...  \
# 0        0.0     138.29          NaN         NaN         NaN  ...
# 1        0.0     172.00          NaN         NaN         NaN  ...
# 2        0.0     179.31          NaN         NaN         NaN  ...
# 3        0.0     172.08          NaN         NaN         NaN  ...
# 4        0.0     145.20          NaN         NaN         NaN  ...
#
#    v_yellow_std  v_yellow_min  v_yellow_max  current_mean  current_std  \
# 0           NaN           NaN           NaN      0.079853     0.044804
# 1           NaN           NaN           NaN      0.060486     0.050824
# 2           NaN           NaN           NaN      0.074063     0.050556
# 3           NaN           NaN           NaN      0.082743     0.048458
# 4           NaN           NaN           NaN      0.000000     0.000000
#
#    current_min  current_max  power_factor_mean  power_factor_min  \
# 0          0.0         0.13           0.384118               0.0
# 1          0.0         0.14           0.342986               0.0
# 2          0.0         0.16           0.399896               0.0
# 3          0.0         0.14           0.356250               0.0
# 4          0.0         0.00           0.000000               0.0
#
#    power_factor_max
# 0              0.77
# 1              0.80
# 2              0.80
# 3              0.94
# 4              0.00
#
# [5 rows x 22 columns]
# 2025-06-05 12:04:31,491 - INFO - ENRICHED DATA AGGREGATION completed in 9.85 seconds

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# **Online/Offline Data Separation**

# %%
# Online/Offline Data Separation

start_time = time.time()

logger.info("Separating data into online and offline days by week...")

# Add Year column and extract Date components
daily_data['Year'] = daily_data['Date'].dt.year

# Add column for week number
daily_data['Week'] = daily_data['Date'].dt.isocalendar().week
daily_data['Year_Week'] = daily_data['Year'].astype(str) + '_' + daily_data['Week'].astype(str)

# Identify sources that have zero consumption for an entire week
offline_weeks_by_source = []

# For each source and each week
for source, group in daily_data.groupby(['Source', 'Year_Week']):
    # If all days of the week have zero consumption
    if (group['kwh_sum'] == 0).all():
        offline_weeks_by_source.append(source)

# Mark days as offline if they belong to a source and week where all days have zero consumption
daily_data['is_offline'] = daily_data.apply(
    lambda row: (row['Source'], row['Year_Week']) in offline_weeks_by_source, 
    axis=1
)

# Separate into online and offline days
offline_data = daily_data[daily_data['is_offline']].copy()
online_data = daily_data[~daily_data['is_offline']].copy()


# FILTERING FOR TEST USERS

# Get list of users in test data
test_users = ss['ID'].str.extract(r'consumer_device_\d+_data_user_(\d+)')[0].astype(int).unique()

# Filter training data to only include users that are in test set
online_data['data_user'] = online_data['Source'].str.extract(r'consumer_device_\d+_data_user_(\d+)')[0].astype(int)
original_count = len(online_data)
online_data = online_data[online_data['data_user'].isin(test_users)]
logger.info(f"User filtering: {original_count - len(online_data)} records removed")

# Save online/offline data
online_data.to_csv('output/filtred_online_days_enriched.csv', index=False)
offline_data.to_csv('output/offline_days_enriched.csv', index=False)
logger.info(f"Online days: {len(online_data):,}, Offline days: {len(offline_data):,}")

# Visualize online vs offline patterns
plt.figure(figsize=(12, 6))
online_counts = online_data.groupby('Date').size()
offline_counts = offline_data.groupby('Date').size()

plt.plot(online_counts.index, online_counts, label='Online Days')
plt.plot(offline_counts.index, offline_counts, label='Offline Days')
plt.title('Online vs Offline Days Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Devices')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

elapsed = time.time() - start_time
logger.info(f"ONLINE/OFFLINE DATA SEPARATION completed in {elapsed:.2f} seconds")
# Out:
# 2025-06-05 12:13:47,949 - INFO - Separating data into online and offline days by week...
# 2025-06-05 12:14:04,120 - INFO - User filtering: 6769 records removed
# 2025-06-05 12:14:05,630 - INFO - Online days: 26,298, Offline days: 50,425
# 2025-06-05 12:14:06,650 - INFO - ONLINE/OFFLINE DATA SEPARATION completed in 18.70 seconds

# %% [markdown]
# ##### Identifying Active vs. Inactive Consumption
#
# To tell the difference between times when a data source is actually being used and when it's completely idle, I organize the data by its **source** and by **week**.
#
# If a source shows **zero daily consumption** for every single day within a given week, that entire week is marked as **'offline.'** These 'offline' periods are then separated into their own dataset called `offline_data`.
#
# Conversely, any weeks where there's **actual consumption** (even if some days are zero) stay in the main dataset, which I call `online_data`.
#
# This method helps ensure that our analysis and models of consumption focus primarily on periods where there's **normal or fluctuating usage**, and we don't skew our understanding with intervals of complete inactivity.

# %%
# Basic Data Inspection (Online_Data)

print("\n===== BASIC DATASET INFORMATION =====")
print(f"Shape: {online_data.shape}")
print(f"Time period: {online_data['Date'].min()} to {online_data['Date'].max()}")
print(f"Number of unique sources: {online_data['Source'].nunique()}")

# Convert Date to datetime (redundant if it's already date; safe to leave in if we want)
online_data['Date'] = pd.to_datetime(online_data['Date'])

#  EDA & Visualizations
import calendar
import os

# Create EDA directory
os.makedirs('output/eda', exist_ok=True)

# Additional columns for EDA
online_data['Month'] = online_data['Date'].dt.month
online_data['Day'] = online_data['Date'].dt.day
online_data['Year'] = online_data['Date'].dt.year
online_data['DayOfWeek'] = online_data['Date'].dt.dayofweek
online_data['WeekOfYear'] = online_data['Date'].dt.isocalendar().week

# Convert device / user if needed
online_data['consumer_device'] = online_data['Source'].str.extract(r'consumer_device_(\d+)_data_user_\d+').astype(int)
online_data['data_user'] = online_data['Source'].str.extract(r'consumer_device_\d+_data_user_(\d+)').astype(int)

print("\n===== ENERGY CONSUMPTION STATISTICS =====")
print(online_data['kwh_sum'].describe())  # or 'kwh' if you’re using sum vs. single record

# 1) Distribution of energy consumption
plt.figure(figsize=(12, 6))
sns.histplot(online_data['kwh_sum'], bins=50, kde=True)
plt.title('Distribution of Energy Consumption (Online Days)')
plt.xlabel('Energy Consumption (kWh)')
plt.ylabel('Frequency')
plt.savefig('output/eda/energy_distribution.png')

# 2) Consumption by Month
monthly_consumption = online_data.groupby('Month')['kwh_sum'].agg(['mean', 'median', 'std', 'count']).reset_index()
monthly_consumption['month_name'] = monthly_consumption['Month'].apply(lambda x: calendar.month_name[x])
monthly_consumption = monthly_consumption.sort_values('Month')

plt.figure(figsize=(12, 6))
sns.barplot(x='month_name', y='mean', data=monthly_consumption)
plt.title('Average Energy Consumption by Month')
plt.xlabel('Month')
plt.ylabel('Average Consumption (kWh)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('output/eda/monthly_consumption.png')

# 3) Consumption by Day of Week
dow_consumption = online_data.groupby('DayOfWeek')['kwh_sum'].agg(['mean', 'median', 'std', 'count']).reset_index()
dow_consumption['day_name'] = dow_consumption['DayOfWeek'].apply(lambda x: calendar.day_name[x])
dow_consumption = dow_consumption.sort_values('DayOfWeek')

plt.figure(figsize=(12, 6))
sns.barplot(x='day_name', y='mean', data=dow_consumption)
plt.title('Average Energy Consumption by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Average Consumption (kWh)')
plt.tight_layout()
plt.savefig('output/eda/dayofweek_consumption.png')

# 4) Daily Trend
daily_avg = online_data.groupby('Date')['kwh_sum'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(daily_avg['Date'], daily_avg['kwh_sum'])
plt.title('Average Daily Energy Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Average Consumption (kWh)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('output/eda/daily_consumption_trend.png')

# CALENDAR HEATMAPS OF AVERAGE kwh_sum

online_df = online_data.copy()
# Ensure 'Date' is a datetime, if not already
online_df['Date'] = pd.to_datetime(online_df['Date'])

# Extract components for pivoting
online_df['Year'] = online_df['Date'].dt.year
online_df['Month'] = online_df['Date'].dt.month
online_df['Day'] = online_df['Date'].dt.day

# For each unique year, pivot data so that:
# Rows = Day, Columns = Month, Values = AVERAGE kwh_sum
years = sorted(online_df['Year'].unique())

for year in years:
    year_df = online_df[online_df['Year'] == year].copy()
    
    # 1) Group by (Month, Day) and compute mean kwh_sum
    pivot_df = (
        year_df
        .groupby(['Month', 'Day'], as_index=False)['kwh_sum']
        .mean()
    )
    
    # 2) Pivot => row=Day, column=Month, value=mean(kwh_sum)
    heatmap_data = pivot_df.pivot(index='Day', columns='Month', values='kwh_sum')
    
    # Build month labels: e.g. 'Jan', 'Feb'...
    month_labels = [calendar.month_abbr[m] for m in range(1, 13)]
    
    # 3) Plot the heatmap
    plt.figure(figsize=(14, 9))
    ax = sns.heatmap(
        heatmap_data,
        cmap='YlOrRd',
        # You can set vmin/vmax if you want consistent color scaling across years
        # vmin=0, vmax=heatmap_data.max().max(),
        xticklabels=month_labels,
        yticklabels=range(1, 32),
        linewidths=0.5,
        linecolor='gray',
        cbar_kws={'label': 'Average kwh_sum'}
    )
    
    plt.title(f'Calendar Heatmap of Average kwh_sum – Year {year}')
    plt.xlabel('Month')
    plt.ylabel('Day of Month')
    plt.tight_layout()
    plt.show()
    plt.close()

#Drop additionnal columns created for EDA
online_data.drop(['Year', 'Month', 'Day', 'DayOfWeek', 'WeekOfYear'], axis=1, inplace=True)
# Out:
# ===== BASIC DATASET INFORMATION =====
# Shape: (26298, 27)
# Time period: 2023-06-24 00:00:00 to 2024-09-23 00:00:00
# Number of unique sources: 333
#
# ===== ENERGY CONSUMPTION STATISTICS =====
# count    26298.000000
# mean         2.805228
# std          8.037298
# min          0.000000
# 25%          0.013006
# 50%          0.098430
# 75%          1.192913
# max        122.522994
# Name: kwh_sum, dtype: float64
# 2025-06-05 12:36:51,173 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-06-05 12:36:51,187 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-06-05 12:36:51,449 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-06-05 12:36:51,464 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# **By analyzing the average daily consumption plot, we identified distinct behavioral patterns during specific date ranges. Based on these observations, our segmentation strategy is as follows:**

# %% [markdown]
# ***1. Data1 (Aug–Sep 2024 & Oct 2023):*** Late summer/early fall, where consumption is notably high. We trained a dedicated model for these intervals and assigned it a higher ensemble weight, since this segment closely aligns with the test period’s expected usage.
#
# ***2. Data2 (Nov–Dec 2023 & Jul 2024):*** Winter and mid-summer, which show moderate consumption. A separate model captures these mid-range patterns.
#
# ***3. Data3 (All other intervals):*** Primarily characterized by zero or very low usage, thereby isolating near-inactive periods so they do not overshadow higher-consumption dynamics.
#
# ***4. Data4 (Entire dataset):*** A global model that unifies all intervals, ensuring broad coverage of overall consumption behavior.

# %% [markdown]
# ## 5. Data or Feature Engineering

# %% [markdown]
# This section defines and implements:
#
# 1. A comprehensive set of Pakistan holidays
# 2. Advanced climate features
# 3. Cyclical temporal encodings
# 4. Temperature trend indicators
# Special features for seasonal patterns in the Klam Climate Data
#
# ***Reload filtred_online_days_enriched data again to avoid any conflicts with columns that may be created during the EDA Process***

# %%
# 1. Loading Online Days Data for Feature Engineering and Training

logger.info("Loading enriched online data...")
start_time = time.time()

# Daily enriched online data
online_data = pd.read_csv("output/filtred_online_days_enriched.csv")
logger.info(f"✓ Enriched online data loaded: {len(online_data):,} records")

# Date conversion
online_data['Date'] = pd.to_datetime(online_data['Date'])
if 'Year' not in online_data.columns:
    online_data['Year'] = online_data['Date'].dt.year  # fallback
else:
    online_data['Year'] = online_data['Year']

# Loading sample submission file
ss = pd.read_csv('SampleSubmission.csv')
logger.info(f"✓ Sample submission loaded: {len(ss):,} records")

# Loading climate data
climate_df = pd.read_excel('ClimateData.xlsx')
logger.info(f"✓ Climate data loaded: {len(climate_df):,} records")

elapsed = time.time() - start_time
logger.info(f"Data loading completed in {elapsed:.2f} seconds")

# Min/max dates
min_date = online_data['Date'].min()
max_date = online_data['Date'].max()
logger.info(f"Period covered: {min_date} to {max_date}")
years_available = online_data['Year'].unique()
logger.info(f"Available years in the data: {years_available}")
# Out:
# 2025-06-05 12:53:36,243 - INFO - Loading enriched online data...
# 2025-06-05 12:53:36,391 - INFO - ✓ Enriched online data loaded: 26,298 records
# 2025-06-05 12:53:36,410 - INFO - ✓ Sample submission loaded: 6,014 records
# 2025-06-05 12:53:38,835 - INFO - ✓ Climate data loaded: 12,228 records
# 2025-06-05 12:53:38,835 - INFO - Data loading completed in 2.59 seconds
# 2025-06-05 12:53:38,845 - INFO - Period covered: 2023-06-24 00:00:00 to 2024-09-23 00:00:00
# 2025-06-05 12:53:38,848 - INFO - Available years in the data: [2024 2023]

# %%
# 2. Defining Pakistan Holidays and Seasons (Kalams)

def get_pakistan_holidays(start_date, end_date):
    """Creates a list of Pakistan holidays for a given period."""
    # Convert to datetime if not already done
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    
    # List of fixed holidays (approx. for lunar holidays)
    holidays = []
    
    # 2023 holidays
    if start_date <= pd.to_datetime("2023-12-31"):
        holidays.extend([
            ("2023-02-05", "Kashmir Day"),
            ("2023-03-23", "Pakistan Day"),
            ("2023-05-01", "Labour Day"),
            ("2023-06-29", "Eid ul Adha"), # approx dates for lunar calendars
            ("2023-06-30", "Eid ul Adha"),
            ("2023-07-01", "Eid ul Adha"),
            ("2023-08-14", "Independence Day"),
            ("2023-09-27", "Eid Milad-un-Nabi"),
            ("2023-11-09", "Iqbal Day"),
            ("2023-12-25", "Quaid-e-Azam Day/Christmas")
        ])
    
    # 2024 holidays
    if start_date <= pd.to_datetime("2024-12-31") and end_date >= pd.to_datetime("2024-01-01"):
        holidays.extend([
            ("2024-02-05", "Kashmir Day"),
            ("2024-03-23", "Pakistan Day"),
            ("2024-05-01", "Labour Day"),
            ("2024-06-17", "Eid ul Adha"), # approx dates
            ("2024-06-18", "Eid ul Adha"),
            ("2024-06-19", "Eid ul Adha"),
            ("2024-08-14", "Independence Day"),
            ("2024-09-16", "Eid Milad-un-Nabi"),
            ("2024-11-09", "Iqbal Day"),
            ("2024-12-25", "Quaid-e-Azam Day/Christmas")
        ])
    
    # Filter dates in the specified range
    holiday_dates = [pd.to_datetime(date) for date, _ in holidays 
                     if pd.to_datetime(date) >= start_date and pd.to_datetime(date) <= end_date]
    
    return holiday_dates

# 3. Advanced Function to Add Features

def add_advanced_features(df, climate_df):
    """Adds advanced features for energy prediction."""
    logger.info("Adding advanced features...")
    
    # Date conversion if necessary
    climate_df['Date Time'] = pd.to_datetime(climate_df['Date Time'])
    
    # Preparing climate data with advanced statistics
    climate_daily = (
        climate_df.groupby(climate_df['Date Time'].dt.date)
        .agg({
            'Temperature (°C)': ['mean', 'min', 'max', 'std'],
            'Dewpoint Temperature (°C)': ['mean', 'min', 'max'],
            'U Wind Component (m/s)': ['mean', 'max'],
            'V Wind Component (m/s)': ['mean', 'max'],
            'Total Precipitation (mm)': ['sum', 'max'],
            'Snowfall (mm)': ['sum', 'max'],
            'Snow Cover (%)': ['mean', 'max'],
        })
        .reset_index()
    )
    
    # Flatten multi-index column names
    climate_daily.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in climate_daily.columns]
    
    # Rename the column correctly after flattening
    if 'Date Time_' in climate_daily.columns:
        climate_daily.rename(columns={'Date Time_': 'Date'}, inplace=True)
    elif 'Date Time' in climate_daily.columns:
        climate_daily.rename(columns={'Date Time': 'Date'}, inplace=True)
    else:
        # Fallback in case the column name is different
        first_col = climate_daily.columns[0]
        climate_daily.rename(columns={first_col: 'Date'}, inplace=True)
        logger.warning(f"Unable to find 'Date Time', used {first_col} as Date column")
    
    climate_daily['Date'] = pd.to_datetime(climate_daily['Date'])
    
    # Merge with climate data
    df = df.merge(climate_daily, on='Date', how='left')
    
    # Calculate temperature variations
    df['temp_daily_range'] = df['Temperature (°C)_max'] - df['Temperature (°C)_min']
    
    # Extract consumer_device / data_user if not already done
    if 'consumer_device' not in df.columns:
        df['consumer_device'] = df['Source'].str.extract(r'consumer_device_(\d+)_data_user_\d+').astype(int)
        df['data_user'] = df['Source'].str.extract(r'consumer_device_\d+_data_user_(\d+)').astype(int)
    
    
    # 1. Cyclical Temporal Features
    
    # Cyclical encoding of day of week (0-6)
    df['day_of_week'] = df['Date'].dt.dayofweek
    df['dow_sin'] = np.sin(df['day_of_week'] * (2 * np.pi / 7))
    df['dow_cos'] = np.cos(df['day_of_week'] * (2 * np.pi / 7))
    
    # Cyclical encoding of day of year (1-366)
    df['day_of_year'] = df['Date'].dt.dayofyear
    df['doy_sin'] = np.sin(df['day_of_year'] * (2 * np.pi / 365.25))
    df['doy_cos'] = np.cos(df['day_of_year'] * (2 * np.pi / 365.25))
    
    # Cyclical encoding of month (1-12)
    df['Month'] = df['Date'].dt.month
    df['month_sin'] = np.sin(df['Month'] * (2 * np.pi / 12))
    df['month_cos'] = np.cos(df['Month'] * (2 * np.pi / 12))
    
    # Cyclical encoding of week (1-53)
    df['Week'] = df['Date'].dt.isocalendar().week
    df['week_sin'] = np.sin(df['Week'] * (2 * np.pi / 53))
    df['week_cos'] = np.cos(df['Week'] * (2 * np.pi / 53))
    
    # Identification of seasons (Kalam has very distinct seasons)
    # For Pakistan: Winter (Dec-Feb), Spring (Mar-May), Summer (Jun-Aug), Fall (Sep-Nov)
    season_map = {1: 1, 2: 1, 3: 2, 4: 2, 5: 2, 6: 3, 7: 3, 8: 3, 9: 4, 10: 4, 11: 4, 12: 1}
    df['season'] = df['Month'].map(season_map)
    df['season_sin'] = np.sin(df['season'] * (2 * np.pi / 4))
    df['season_cos'] = np.cos(df['season'] * (2 * np.pi / 4))
    
    # Weekend indicator
    df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)
    
    # 2. Holidays and more granular seasonal features
    
    holidays = get_pakistan_holidays(df['Date'].min(), df['Date'].max())
    df['is_holiday'] = df['Date'].isin(holidays).astype(int)
    
    # Week of the year
    df['week_in_year'] = df['Date'].dt.isocalendar().week
    
    # Days since the beginning of each season
    spring_start, spring_end = 60, 151  # Mar 1 - May 31 (approx days of year)
    summer_start, summer_end = 152, 243  # Jun 1 - Aug 31
    fall_start, fall_end = 244, 334  # Sep 1 - Nov 30
    # Winter wraps around year end
    
    df['day_in_season'] = np.nan
    
    # Calculate days since start of each season
    mask_spring = (df['day_of_year'] >= spring_start) & (df['day_of_year'] <= spring_end)
    mask_summer = (df['day_of_year'] >= summer_start) & (df['day_of_year'] <= summer_end)
    mask_fall = (df['day_of_year'] >= fall_start) & (df['day_of_year'] <= fall_end)
    mask_winter = (~mask_spring) & (~mask_summer) & (~mask_fall)
    
    df.loc[mask_spring, 'day_in_season'] = df.loc[mask_spring, 'day_of_year'] - spring_start
    df.loc[mask_summer, 'day_in_season'] = df.loc[mask_summer, 'day_of_year'] - summer_start
    df.loc[mask_fall, 'day_in_season'] = df.loc[mask_fall, 'day_of_year'] - fall_start
    df.loc[mask_winter & (df['day_of_year'] >= 335), 'day_in_season'] = df.loc[mask_winter & (df['day_of_year'] >= 335), 'day_of_year'] - 335
    df.loc[mask_winter & (df['day_of_year'] < 60), 'day_in_season'] = df.loc[mask_winter & (df['day_of_year'] < 60), 'day_of_year'] + 31  # Days after Jan 1
    
    # Create cyclical features for day in season
    df['day_in_season_sin'] = np.sin(df['day_in_season'] * (2 * np.pi / 90))  # ~90 days per season
    df['day_in_season_cos'] = np.cos(df['day_in_season'] * (2 * np.pi / 90))
    
    # Ramadan dates (important for Pakistan)
    ramadan_2023_start = pd.to_datetime('2023-03-23')
    ramadan_2023_end = pd.to_datetime('2023-04-21')
    ramadan_2024_start = pd.to_datetime('2024-03-11')  
    ramadan_2024_end = pd.to_datetime('2024-04-09')
    
    df['is_ramadan'] = (
        ((df['Date'] >= ramadan_2023_start) & (df['Date'] <= ramadan_2023_end)) | 
        ((df['Date'] >= ramadan_2024_start) & (df['Date'] <= ramadan_2024_end))
    ).astype(int)
    
    # 3. Climate-related Features
    
    # Temperature and dew point
    df['temp_dew_diff'] = df['Temperature (°C)_mean'] - df['Dewpoint Temperature (°C)_mean']
    
    # Wind speed calculated from U and V components
    df['wind_speed'] = np.sqrt(df['U Wind Component (m/s)_mean']**2 + df['V Wind Component (m/s)_mean']**2)
    df['wind_speed_max'] = np.sqrt(df['U Wind Component (m/s)_max']**2 + df['V Wind Component (m/s)_max']**2)
    
    # Precipitation/snow ratio
    df['precip_snow_ratio'] = df['Total Precipitation (mm)_sum'] / (df['Snowfall (mm)_sum'] + 1e-6)
    
    # Degree days (heating/cooling) - base 18°C
    df['heating_degree_days'] = np.maximum(18 - df['Temperature (°C)_mean'], 0)
    df['cooling_degree_days'] = np.maximum(df['Temperature (°C)_mean'] - 18, 0)
    
    # Temperature-day of week interaction
    for day in range(7):
        df[f'temp_dow_{day}'] = np.where(df['day_of_week'] == day, df['Temperature (°C)_mean'], 0)
    
    # 4. Advanced Temperature Trend Features
    
    # Sort data to calculate correct trends
    df = df.sort_values(['Source', 'Date']).reset_index(drop=True)
    
    # Create trends by source
    for source in df['Source'].unique():
        source_mask = df['Source'] == source
        if sum(source_mask) > 7:  # At least one week of data
            # Exponential moving averages
            df.loc[source_mask, 'temp_ewm_3d'] = df.loc[source_mask, 'Temperature (°C)_mean'].ewm(span=3).mean()
            df.loc[source_mask, 'temp_ewm_7d'] = df.loc[source_mask, 'Temperature (°C)_mean'].ewm(span=7).mean()
            
            # Temperature volatility (rolling standard deviation)
            df.loc[source_mask, 'temp_volatility_7d'] = df.loc[source_mask, 'Temperature (°C)_mean'].rolling(window=7, min_periods=1).std()
            
            # Temperature acceleration (change of rate of change)
            temp = df.loc[source_mask, 'Temperature (°C)_mean']
            df.loc[source_mask, 'temp_acceleration'] = temp.diff().diff().fillna(0)
            
            # Temperature trend direction (up or down)
            df.loc[source_mask, 'temp_trend_direction'] = np.sign(temp.diff(periods=3)).fillna(0)
            
            # Temperature extreme indicator (sudden peaks or drops)
            rolling_mean = temp.rolling(window=7, min_periods=1).mean()
            rolling_std = temp.rolling(window=7, min_periods=1).std().fillna(1)  # Avoid division by zero
            df.loc[source_mask, 'temp_extreme'] = ((temp - rolling_mean).abs() / rolling_std).fillna(0)


    # Convert categorical columns
    df['Source'] = df['Source'].astype('category')
    if 'consumer_device' in df.columns:
        df['consumer_device'] = df['consumer_device'].astype('category')
    if 'data_user' in df.columns:
        df['data_user'] = df['data_user'].astype('category')
    
    # Fill NaNs
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)

    
    return df

# %% [markdown]
# ### Data Segmentation

# %% [markdown]
# To capture different seasonal patterns, I segment the data into four groups:
#
# 1. Data1: Late summer/early fall (Aug-Sep 2024, Oct 2023)
# 2. Data2: Winter and mid-summer (Nov-Dec 2023, Jul 2024)
# 3. Data3: All other periods with distinct patterns
# 4. Data4: The complete dataset for a global model

# %%
# Data Segmentation & Preparation

logger.info("Separating data according to new ranges...")

# Data1 = August 1 -> September 23, 2024, AND all October 2023
mask_data1 = (
    ((online_data['Date'] >= '2024-08-01') & (online_data['Date'] <= '2024-09-23')) |
    ((online_data['Date'] >= '2023-10-01') & (online_data['Date'] <= '2023-10-31'))
)
data1 = online_data[mask_data1].copy()

# Data2 = November 1 -> December 31, 2023, AND all July 2024
mask_data2 = (
    ((online_data['Date'] >= '2023-11-01') & (online_data['Date'] <= '2023-12-31')) |
    ((online_data['Date'] >= '2024-07-01') & (online_data['Date'] <= '2024-07-31'))
)
data2 = online_data[mask_data2].copy()

# Data3 = the rest
mask_data3 = ~(mask_data1 | mask_data2)
data3 = online_data[mask_data3].copy()

logger.info(f"Data1: {len(data1):,} records")
logger.info(f"Data2: {len(data2):,} records")
logger.info(f"Data3: {len(data3):,} records")

# Visualize the data distribution across segments
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.histplot(data1['kwh_sum'], bins=50, kde=True)
plt.title('Energy Distribution - Data1 (Late Summer/Fall)')
plt.xlabel('kWh')

plt.subplot(2, 2, 2)
sns.histplot(data2['kwh_sum'], bins=50, kde=True)
plt.title('Energy Distribution - Data2 (Winter/Mid-Summer)')
plt.xlabel('kWh')

plt.subplot(2, 2, 3)
sns.histplot(data3['kwh_sum'], bins=50, kde=True)
plt.title('Energy Distribution - Data3 (Other Periods)')
plt.xlabel('kWh')

plt.subplot(2, 2, 4)
sns.histplot(online_data['kwh_sum'], bins=50, kde=True)
plt.title('Energy Distribution - All Data')
plt.xlabel('kWh')

plt.tight_layout()
plt.show()

# Function to prepare complete datasets
def prepare_complete_data(agg_data, start_date=None, end_date=None):
    """Creates a complete dataframe (missing dates) for each Source."""
    if len(agg_data) == 0:
        logger.warning("Empty dataset, creation impossible.")
        return pd.DataFrame()
    
    if start_date is None:
        start_date = agg_data['Date'].min()
    if end_date is None:
        end_date = agg_data['Date'].max()
    
    logger.info(f"Creating complete dataset for period {start_date} to {end_date}")
    
    complete_data = pd.DataFrame()
    date_rng = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Determine which column contains consumption data
    kwh_col = 'kwh_sum' if 'kwh_sum' in agg_data.columns else 'kwh'
    
    for src in agg_data['Source'].unique():
        subset = agg_data[agg_data['Source'] == src].copy()
        rng_df = pd.DataFrame({'Date': date_rng})
        rng_df['Source'] = src
        
        merged = pd.merge(rng_df, subset, on=['Date','Source'], how='left')
        # Remove rows without consumption (as we're already dealing with online only)
        merged.dropna(subset=[kwh_col], inplace=True)
        
        complete_data = pd.concat([complete_data, merged], ignore_index=True)
    
    logger.info(f"Complete data after filtering: {len(complete_data)} records")
    return complete_data

# Prepare and enhance the datasets
logger.info("Preparing 4 complete datasets with advanced features...")

# Dataset preparation
complete_data_1 = prepare_complete_data(data1)
complete_data_2 = prepare_complete_data(data2)
complete_data_3 = prepare_complete_data(data3)
complete_data_4 = prepare_complete_data(online_data)  # The whole period

# Adding advanced features
complete_data_1 = add_advanced_features(complete_data_1, climate_df)
complete_data_2 = add_advanced_features(complete_data_2, climate_df)
complete_data_3 = add_advanced_features(complete_data_3, climate_df)
complete_data_4 = add_advanced_features(complete_data_4, climate_df)

# Display feature counts
feature_counts = pd.DataFrame({
    'Data1': len(complete_data_1.columns),
    'Data2': len(complete_data_2.columns),
    'Data3': len(complete_data_3.columns),
    'Data4': len(complete_data_4.columns)
}, index=['Feature Count'])
display(feature_counts)
# Out:
# 2025-06-05 13:09:07,230 - INFO - Separating data according to new ranges...
# 2025-06-05 13:09:07,246 - INFO - Data1: 14,983 records
# 2025-06-05 13:09:07,247 - INFO - Data2: 11,313 records
# 2025-06-05 13:09:07,247 - INFO - Data3: 2 records
# 2025-06-05 13:09:08,504 - INFO - Preparing 4 complete datasets with advanced features...
# 2025-06-05 13:09:08,504 - INFO - Creating complete dataset for period 2023-10-01 00:00:00 to 2024-09-23 00:00:00
# 2025-06-05 13:09:11,064 - INFO - Complete data after filtering: 14983 records
# 2025-06-05 13:09:11,067 - INFO - Creating complete dataset for period 2023-11-01 00:00:00 to 2024-07-31 00:00:00
# 2025-06-05 13:09:13,547 - INFO - Complete data after filtering: 11313 records
# 2025-06-05 13:09:13,547 - INFO - Creating complete dataset for period 2023-06-24 00:00:00 to 2023-06-25 00:00:00
# 2025-06-05 13:09:13,554 - INFO - Complete data after filtering: 2 records
# 2025-06-05 13:09:13,555 - INFO - Creating complete dataset for period 2023-06-24 00:00:00 to 2024-09-23 00:00:00
# 2025-06-05 13:09:16,812 - INFO - Complete data after filtering: 26298 records
# 2025-06-05 13:09:16,812 - INFO - Adding advanced features...
# 2025-06-05 13:09:19,793 - INFO - Adding advanced features...
# 2025-06-05 13:09:22,554 - INFO - Adding advanced features...
# 2025-06-05 13:09:22,637 - INFO - Adding advanced features...
#                Data1  Data2  Data3  Data4
# Feature Count     86     86     80     86

# %% [markdown]
# ## 6. Modelling & Model Training Functions

# %% [markdown]
# This section implements:
#
# 1. A cross-validation training function with Bayesian optimization for ensemble weights
# 2. A direct training function for smaller datasets
# 3. A prediction function that handles both ensemble and single models
#
# The CV training function trains 7 different LightGBM models with varied configurations, then uses Bayesian optimization to find the optimal weights for combining their predictions.

# %%
def train_model_cv(data, model_name, n_folds=5):
    """
    Trains a stack of 7 LGBM models with different parameters.
    Uses Bayesian optimization to find optimal weights.
    Returns: (models, used_columns, cv_scores, oof_predictions, oof_rmse)
    """
    logger.info(f"========== START TRAINING {model_name} ==========")
    logger.info(f"Training {model_name} with stacking of 7 LGBMs (CV {n_folds}-folds)...")
    logger.info(f"Input data: {len(data)} samples with {len(data.columns)} columns")
    
    start_time = time.time()
    
    # Determine target column (kwh or kwh_sum)
    target_col = 'kwh_sum' if 'kwh_sum' in data.columns else 'kwh'
    logger.info(f"Detected target column: {target_col}")
    
    # List of columns to exclude from training
    exclude_cols = [
        'Date', 'kwh', 'kwh_sum', 'Year_Week', 'is_offline', 
        'Month', 'day_of_week', 'day_of_year', 'Week', 'Year',
        'consumer_device', 'data_user', 'current_mean', 'current_std', 'current_min', 'current_max',
        'v_red_mean', 'v_red_std', 'v_red_min', 'v_red_max', 
        'v_blue_mean', 'v_blue_std', 'v_blue_min', 'v_blue_max',
        'v_yellow_mean', 'v_yellow_std', 'v_yellow_min', 'v_yellow_max',
        'power_factor_mean', 'power_factor_min', 'power_factor_max'
    ]
    
    # Remove columns with too many NaNs
    nan_cols = []
    for col in data.columns:
        if col not in exclude_cols and data[col].isna().mean() > 0.5:  # More than 50% NaN
            exclude_cols.append(col)
            nan_cols.append(col)
    
    if nan_cols:
        logger.info(f"Columns excluded due to too many NaNs: {', '.join(nan_cols)}")
    
    logger.info(f"Total of {len(exclude_cols)} columns excluded from training")
    
    X = data.drop(columns=exclude_cols, errors='ignore')
    y = data[target_col].values
    #y = np.log1p(np.maximum(0, y_raw))
    
    logger.info(f"Prepared dataset: X shape={X.shape}, y shape={y.shape}")
    logger.info(f"Target statistics: min={y.min():.4f}, max={y.max():.4f}, mean={y.mean():.4f}, median={np.median(y):.4f}")
    
    # Identification of categorical features
    cat_feats = ['Source']
    if 'is_three_phase' in X.columns:
        cat_feats.append('is_three_phase')
    if 'season' in X.columns:
        cat_feats.append('season')
    
    logger.info(f"Detected categorical features: {', '.join(cat_feats)}")
    
    # 7 different LightGBM configurations
    lgbm_configs = [
        # Model 1: Precise, more conservative (original)
        {
            'name': 'precise',
            'params': {
                'n_estimators': 2000,
                'learning_rate': 0.01,
                'max_depth': 8,
                'num_leaves': 31,
                'colsample_bytree': 0.8,
                'subsample': 0.8,
                'reg_alpha': 0.1,
                'reg_lambda': 0.1,
                'min_child_weight': 10,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 100
            }
        },
        # Model 2: More aggressive on feature selection (original)
        {
            'name': 'feature_selective',
            'params': {
                'n_estimators': 1500,
                'learning_rate': 0.02,
                'max_depth': 6,
                'colsample_bytree': 0.6,
                'subsample': 0.9,
                'reg_alpha': 1.0,
                'reg_lambda': 0.1,
                'feature_fraction': 0.7,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 100
            }
        },
        # Model 3: Focus on robustness to outliers (original)
        {
            'name': 'robust',
            'params': {
                'n_estimators': 1000,
                'learning_rate': 0.03,
                'max_depth': 5,
                'colsample_bytree': 0.9,
                'subsample': 0.7,
                'reg_alpha': 0.5,
                'reg_lambda': 1.0,
                'min_data_in_leaf': 20,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 100
            }
        },
        # Model 4: Very deep with many trees (new)
        {
            'name': 'deep_forest',
            'params': {
                'n_estimators': 3000,
                'learning_rate': 0.005,
                'max_depth': 12,
                'num_leaves': 64,
                'colsample_bytree': 0.75,
                'subsample': 0.75,
                'reg_alpha': 0.2,
                'reg_lambda': 0.2,
                'min_child_weight': 5,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 150
            }
        },
        # Model 5: Highly regularized (new)
        {
            'name': 'highly_regularized',
            'params': {
                'n_estimators': 1200,
                'learning_rate': 0.02,
                'max_depth': 4,
                'num_leaves': 16,
                'colsample_bytree': 0.7,
                'subsample': 0.8,
                'reg_alpha': 2.0,
                'reg_lambda': 2.0,
                'min_child_weight': 15,
                'min_data_in_leaf': 25,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 100
            }
        },
        # Model 6: Very fast with high learning rate (new)
        {
            'name': 'fast_learner',
            'params': {
                'n_estimators': 800,
                'learning_rate': 0.08,
                'max_depth': 6,
                'num_leaves': 32,
                'colsample_bytree': 0.85,
                'subsample': 0.85,
                'reg_alpha': 0.3,
                'reg_lambda': 0.3,
                'min_child_weight': 8,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 80
            }
        },
        # Model 7: Optimized for bias-variance trade-off (new)
        {
            'name': 'balanced',
            'params': {
                'n_estimators': 1800,
                'learning_rate': 0.015,
                'max_depth': 7,
                'num_leaves': 40,
                'colsample_bytree': 0.75,
                'subsample': 0.85,
                'reg_alpha': 0.4,
                'reg_lambda': 0.4,
                'min_child_weight': 12,
                'bagging_freq': 5,
                'random_state': 42,
                'objective': 'rmse',
                'metric': 'rmse',
                'verbose': -1,
                'early_stopping_rounds': 120
            }
        }
    ]
    
    logger.info(f"Configuration of {len(lgbm_configs)} LightGBM models with different parameters")
    
    # Cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    models = []  # Final model list to return (consistent with original function)
    optimal_weights_list = []  # Storage for optimal weights for each fold
    cv_scores = []
    oof_preds = np.zeros(len(data))
    oof_base_preds = np.zeros((len(data), len(lgbm_configs)))
    
    # Training of level 1 (base) models
    logger.info(f"Starting training with {n_folds}-fold cross-validation")
    
    for fold, (tr_idx, val_idx) in enumerate(kf.split(X)):
        fold_start_time = time.time()
        logger.info(f"=====================")
        logger.info(f"Fold {fold+1}/{n_folds} for {model_name}")
        logger.info(f"Train: {len(tr_idx)} samples, Validation: {len(val_idx)} samples")
        
        X_train, X_val = X.iloc[tr_idx], X.iloc[val_idx]
        y_train, y_val = y[tr_idx], y[val_idx]
        
        logger.info(f"y_train statistics: min={y_train.min():.4f}, max={y_train.max():.4f}, mean={y_train.mean():.4f}")
        logger.info(f"y_val statistics: min={y_val.min():.4f}, max={y_val.max():.4f}, mean={y_val.mean():.4f}")
        
        fold_models = []
        fold_preds = np.zeros((len(X_val), len(lgbm_configs)))
        
        # Training each base model
        for i, config in enumerate(lgbm_configs):
            model_start_time = time.time()
            logger.info(f"  ---------------------")
            logger.info(f"  Training base model {i+1}/{len(lgbm_configs)} ({config['name']})...")
            logger.info(f"  Parameters: {json.dumps(config['params'], indent=2)}")
            
            model = LGBMRegressor(**config['params'])
            
            try:
                logger.info(f"  Starting training...")
                model.fit(
                    X_train, y_train,
                    eval_set=[(X_val, y_val)],
                    categorical_feature=cat_feats
                )
                logger.info(f"  Training completed successfully in {time.time() - model_start_time:.2f} seconds")
                logger.info(f"  Best iteration: {model.best_iteration_}")
                
                # Predictions on validation set
                val_preds = model.predict(X_val)
                fold_preds[:, i] = val_preds
                oof_base_preds[val_idx, i] = val_preds
                
                fold_models.append(model)
                
                # Display metrics for this model
                rmse = np.sqrt(mean_squared_error(y_val, val_preds))
                logger.info(f"  Model {config['name']} - RMSE: {rmse:.6f}")
                logger.info(f"  Prediction statistics: min={val_preds.min():.4f}, max={val_preds.max():.4f}, mean={val_preds.mean():.4f}")
                
            except Exception as e:
                logger.error(f"  ERROR during training of model {config['name']}: {str(e)}")
                # Placeholder model with default parameters if training fails
                placeholder_model = LGBMRegressor(n_estimators=100)
                placeholder_model.fit(X_train, y_train)
                fold_models.append(placeholder_model)
                fold_preds[:, i] = placeholder_model.predict(X_val)
                oof_base_preds[val_idx, i] = fold_preds[:, i]
        
        # Instead of using a meta-model, find optimal weights with Bayesian optimization
        logger.info(f"  ---------------------")
        logger.info(f"  Searching for optimal weights with Bayesian optimization...")
        
        # Objective function for Bayesian optimization
        def objective_function(**weights):
            # Convert dictionary to array
            w = np.array([weights[f'w{i}'] for i in range(len(lgbm_configs))])
            
            # Normalize weights to sum to 1
            w = w / np.sum(w)
            
            # Weighted prediction
            weighted_pred = np.zeros(len(y_val))
            for i in range(len(lgbm_configs)):
                weighted_pred += w[i] * fold_preds[:, i]

            #---------------------------------------------
            # Remove NaNs before computing RMSE
            valid_idx = ~np.isnan(weighted_pred)

            # Check if any valid predictions exist
            if np.sum(valid_idx) == 0:
                return -9999  # Penalize this parameter combination

            neg_rmse = -np.sqrt(mean_squared_error(y_val[valid_idx], weighted_pred[valid_idx]))
            return neg_rmse

            # Remove NaNs before computing RMSE
            #valid_idx = ~np.isnan(weighted_pred)
            #neg_rmse = -np.sqrt(mean_squared_error(y_val[valid_idx], weighted_pred[valid_idx]))
            #return neg_rmse
            #-----------------------------------------------------
        
            # Calculate negative error (because we maximize)
            #neg_rmse = -np.sqrt(mean_squared_error(y_val, weighted_pred))
            #return neg_rmse
        
        # Define bounds for optimization - all weights between 0 and 1
        pbounds = {f'w{i}': (0, 1) for i in range(len(lgbm_configs))}
        
        # Run Bayesian optimization
        optimizer = BayesianOptimization(
            f=objective_function,
            pbounds=pbounds,
            random_state=42,
            verbose=0
        )
        
        optimizer.maximize(init_points=10, n_iter=50)
        
        # Get best parameters and normalize
        best_params = optimizer.max['params']
        optimal_weights = np.array([best_params[f'w{i}'] for i in range(len(lgbm_configs))])
        optimal_weights = optimal_weights / np.sum(optimal_weights)
        optimal_weights_list.append(optimal_weights)
        
        # Record optimal weights
        logger.info(f"  Optimal weights found: {', '.join([f'{w:.4f}' for w in optimal_weights])}")
        
        # Calculate final predictions with optimal weights
        final_val_preds = np.zeros(len(y_val))
        for i in range(len(lgbm_configs)):
            final_val_preds += optimal_weights[i] * fold_preds[:, i]
        
        oof_preds[val_idx] = final_val_preds
        
        # Calculate final RMSE
        rmse = np.sqrt(mean_squared_error(y_val, final_val_preds))
        cv_scores.append(rmse)
        logger.info(f"  Bayesian optimization - RMSE: {rmse:.6f}")
        logger.info(f"  Final prediction statistics: min={final_val_preds.min():.4f}, max={final_val_preds.max():.4f}, mean={final_val_preds.mean():.4f}")
        
        # Comparison with simple average
        equal_weights_pred = np.mean(fold_preds, axis=1)
        equal_weights_rmse = np.sqrt(mean_squared_error(y_val, equal_weights_pred))
        improvement = (equal_weights_rmse - rmse) / equal_weights_rmse * 100
        logger.info(f"  RMSE with equal weights: {equal_weights_rmse:.6f}")
        logger.info(f"  Improvement: {improvement:.2f}%")
        
        # Store models and optimal weights
        models.append((fold_models, optimal_weights))
        
        # Display important features (from the first base model)
        if fold == 0 and len(fold_models) > 0:
            try:
                feature_imp = pd.DataFrame({
                    'Value': fold_models[0].feature_importances_,
                    'Feature': X.columns
                }).sort_values(by='Value', ascending=False)
                #logger.info(f"Top 20 important features:\n{feature_imp.head(20)}")
                # Create feature importance plot
                plt.figure(figsize=(12, 6))
                sns.barplot(x='Value', y='Feature', data=feature_imp.head(20))
                plt.title(f'Top 20 Features - {model_name}')
                plt.tight_layout()
                plt.show()
            except Exception as e:
                logger.error(f"Error when displaying important features: {str(e)}")
        
        logger.info(f"Fold {fold+1} completed in {time.time() - fold_start_time:.2f} seconds")
    
    # Calculate global metrics
    mean_cv_score = np.mean(cv_scores)
    std_cv_score = np.std(cv_scores)
    logger.info(f"=====================")
    logger.info(f"CV RMSE for {model_name} (with optimal weights): {mean_cv_score:.6f} ± {std_cv_score:.6f}")
    
    oof_rmse = np.sqrt(mean_squared_error(y, oof_preds))
    logger.info(f"OOF RMSE for {model_name} (with optimal weights): {oof_rmse:.6f}")
    logger.info(f"OOF prediction statistics: min={oof_preds.min():.4f}, max={oof_preds.max():.4f}, mean={oof_preds.mean():.4f}")
    
    # Statistics by base model
    for i, config in enumerate(lgbm_configs):
        base_oof_rmse = np.sqrt(mean_squared_error(y, oof_base_preds[:, i]))
        logger.info(f"OOF RMSE for base model {config['name']}: {base_oof_rmse:.6f}")
    
    # Calculate average optimal weights across all folds
    mean_optimal_weights = np.mean(optimal_weights_list, axis=0)
    mean_optimal_weights = mean_optimal_weights / np.sum(mean_optimal_weights)
    logger.info(f"Average optimal weights across all folds: {', '.join([f'{w:.4f}' for w in mean_optimal_weights])}")
    
    total_time = time.time() - start_time
    logger.info(f"Complete training finished in {total_time:.2f} seconds ({total_time/60:.2f} minutes)")
    logger.info(f"========== END TRAINING {model_name} ==========")
    
    
    return models, X.columns, cv_scores, oof_preds, oof_rmse


# 8. Direct Training Function (No CV)

def train_model_no_cv(data, model_name):
    """Train on the entire dataset with NO validation."""
    logger.info(f"Direct training (NO CV) for {model_name}...")

    # Determine target column (kwh or kwh_sum)
    target_col = 'kwh_sum' if 'kwh_sum' in data.columns else 'kwh'
    
    # List of columns to exclude from training
    exclude_cols = [
        'Date', 'kwh', 'kwh_sum', 'Year_Week', 'is_offline', 
        'Month', 'day_of_week', 'day_of_year', 'Week', 'Year',
        'consumer_device', 'data_user', 'current_mean', 'current_std', 'current_min', 'current_max',
        'v_red_mean', 'v_red_std', 'v_red_min', 'v_red_max', 
        'v_blue_mean', 'v_blue_std', 'v_blue_min', 'v_blue_max',
        'v_yellow_mean', 'v_yellow_std', 'v_yellow_min', 'v_yellow_max',
        'power_factor_mean', 'power_factor_min', 'power_factor_max'
    ]
    
    # Remove columns with too many NaNs
    for col in data.columns:
        if col not in exclude_cols and data[col].isna().mean() > 0.5:  # More than 50% NaN
            exclude_cols.append(col)
    
    X = data.drop(columns=exclude_cols, errors='ignore')
    y = data[target_col].values
    #y = np.log1p(np.maximum(0, y_raw))

    # Identification of categorical features
    cat_feats = ['Source']
    if 'is_three_phase' in X.columns:
        cat_feats.append('is_three_phase')
    if 'season' in X.columns:
        cat_feats.append('season')

    # No early_stopping_rounds
    model = LGBMRegressor(
        n_estimators=50,
        learning_rate=0.03,
        objective='rmse',
        metric='rmse',
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=0.01,
        reg_lambda=0.01,
        random_state=42,
        verbose=-1
    )

    # Fit on entire dataset, no eval_set
    model.fit(X, y, categorical_feature=cat_feats)

    # Return in a list so we stay compatible with "predict_with_cv_models"
    return [model], X.columns


# Function to infer with an ensemble of models
def predict_with_cv_models(models, X, columns):
    """
    Prediction with ensemble of models, using optimal weights found by Bayesian optimization.
    """
    # Log at the beginning of prediction
    logger.info(f"Starting prediction with {len(models)} models on {len(X)} samples...")
    
    # Create a copy of X to avoid modifying the original
    X_use = X.copy()
    
    # We don't need to make sure all columns match exactly
    # Just ensure we have the columns needed for prediction
    needed_cols = [col for col in columns if col in X_use.columns]
    logger.info(f"Using {len(needed_cols)}/{len(columns)} available columns for prediction")
    X_use = X_use[needed_cols]
    
    # Check if models are stacked or simple models
    is_stacked = isinstance(models[0], tuple) and len(models[0]) == 2
    
    if is_stacked:
        logger.info("Detection of stacked models with optimal weights...")
        # Stacked model logic with optimal weights
        final_preds = np.zeros(len(X_use))
        
        # For each fold's models
        for fold_idx, (base_models, optimal_weights) in enumerate(models):
            logger.info(f"  Prediction for fold {fold_idx+1}/{len(models)}...")
            
            # Get predictions from base models
            base_preds = np.zeros((len(X_use), len(base_models)))
            
            for i, model in enumerate(base_models):
                logger.info(f"    Prediction with base model {i+1}/{len(base_models)}...")
                base_preds[:, i] = model.predict(X_use, predict_disable_shape_check=True)
                logger.info(f"    Prediction statistics for model {i+1}: min={base_preds[:, i].min():.4f}, max={base_preds[:, i].max():.4f}, mean={base_preds[:, i].mean():.4f}")
            
            # Apply optimal weights
            logger.info(f"    Applying optimal weights: {', '.join([f'{w:.4f}' for w in optimal_weights])}")
            fold_preds = np.zeros(len(X_use))
            for i in range(len(base_models)):
                fold_preds += optimal_weights[i] * base_preds[:, i]
            
            logger.info(f"    Statistics of weighted predictions: min={fold_preds.min():.4f}, max={fold_preds.max():.4f}, mean={fold_preds.mean():.4f}")
            
            final_preds += fold_preds
        
        # Average predictions across folds
        final_preds = final_preds / len(models)
        logger.info(f"Final predictions (average of {len(models)} folds): min={final_preds.min():.4f}, max={final_preds.max():.4f}, mean={final_preds.mean():.4f}")
        
        return final_preds
    else:
        logger.info("Using simple models...")
        # Original single model logic
        preds = np.zeros(len(X_use))
        for i, m in enumerate(models):
            logger.info(f"  Prediction with model {i+1}/{len(models)}...")
            # Use this parameter to bypass categorical feature validation
            model_preds = m.predict(X_use, predict_disable_shape_check=True)
            logger.info(f"  Prediction statistics for model {i+1}: min={model_preds.min():.4f}, max={model_preds.max():.4f}, mean={model_preds.mean():.4f}")
            preds += model_preds
        
        final_preds = preds / len(models)
        logger.info(f"Final predictions (average of {len(models)} models): min={final_preds.min():.4f}, max={final_preds.max():.4f}, mean={final_preds.mean():.4f}")
        return final_preds

# %% [markdown]
# ## 7. Model Training and Evaluation/Performance

# %% [markdown]
# In this section, we train models for each data segment:
#
# 1. Model 1: Trained on Data1 (late summer/early fall) with 5-fold CV
# 2. Model 2: Trained on Data2 (winter/mid-summer) with 5-fold CV
# 3. Model 3: Trained on Data3 (other periods) with direct training (no CV)
# 4. Model 4: Trained on the complete dataset with 5-fold CV
#
# We evaluate each model using cross-validation metrics and out-of-fold predictions.

# %%
# MODEL TRAINING

# Model 1 - Data1 (late summer/early fall)
logger.info("Training Model 1 (Data1) => 5 folds")
models1, cols1, cv_scores1, oof_preds1, oof_rmse1 = train_model_cv(complete_data_1, "Model_1_Data1", n_folds=5)

# Model 2 - Data2 (winter/mid-summer)
logger.info("Training Model 2 (Data2) => 5 folds")
models2, cols2, cv_scores2, oof_preds2, oof_rmse2 = train_model_cv(complete_data_2, "Model_2_Data2", n_folds=5)

# Model 3 - Data3 (other periods) - No CV
logger.info("Training Model 3 (Data3) => NO CV")
models3, cols3 = train_model_no_cv(complete_data_3, "Model_3_Data3")

# Model 4 - Complete dataset
logger.info("Training Model 4 (Complete Data) => 5 folds")
models4, cols4, cv_scores4, oof_preds4, oof_rmse4 = train_model_cv(complete_data_4, "Model_4_Data4", n_folds=5)

# Display model performance comparison
model_perf = pd.DataFrame({
    'Model': ['Model1 (Data1)', 'Model2 (Data2)', 'Model4 (Complete)'],
    'Mean CV RMSE': [np.mean(cv_scores1), np.mean(cv_scores2), np.mean(cv_scores4)],
    'Std CV RMSE': [np.std(cv_scores1), np.std(cv_scores2), np.std(cv_scores4)],
    'OOF RMSE': [oof_rmse1, oof_rmse2, oof_rmse4]
})
display(model_perf)

# Plot CV scores comparison
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='OOF RMSE', data=model_perf)
plt.title('Model Performance Comparison (OOF RMSE)')
plt.ylabel('RMSE (lower is better)')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# 2025-06-05 15:09:08,260 - INFO - Training Model 1 (Data1) => 5 folds
# 2025-06-05 15:09:08,261 - INFO - ========== START TRAINING Model_1_Data1 ==========
# 2025-06-05 15:09:08,261 - INFO - Training Model_1_Data1 with stacking of 7 LGBMs (CV 5-folds)...
# 2025-06-05 15:09:08,261 - INFO - Input data: 14983 samples with 86 columns
# 2025-06-05 15:09:08,262 - INFO - Detected target column: kwh_sum
# 2025-06-05 15:09:08,284 - INFO - Total of 31 columns excluded from training
# 2025-06-05 15:09:08,292 - INFO - Prepared dataset: X shape=(14983, 56), y shape=(14983,)
# 2025-06-05 15:09:08,294 - INFO - Target statistics: min=0.0000, max=110.8552, mean=3.3712, median=0.1416
# 2025-06-05 15:09:08,295 - INFO - Detected categorical features: Source, season
# 2025-06-05 15:09:08,295 - INFO - Configuration of 7 LightGBM models with different parameters
# 2025-06-05 15:09:08,295 - INFO - Starting training with 5-fold cross-validation
# 2025-06-05 15:09:08,295 - INFO - =====================
# 2025-06-05 15:09:08,295 - INFO - Fold 1/5 for Model_1_Data1
# 2025-06-05 15:09:08,300 - INFO - Train: 11986 samples, Validation: 2997 samples
# 2025-06-05 15:09:08,355 - INFO - y_train statistics: min=0.0000, max=110.8552, mean=3.3971
# 2025-06-05 15:09:08,371 - INFO - y_val statistics: min=0.0000, max=102.0453, mean=3.2678
# 2025-06-05 15:09:08,379 - INFO -   ---------------------
# 2025-06-05 15:09:08,388 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:09:08,389 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:08,390 - INFO -   Starting training...
# 2025-06-05 15:09:12,210 - INFO -   Training completed successfully in 3.83 seconds
# 2025-06-05 15:09:12,211 - INFO -   Best iteration: 2000
# 2025-06-05 15:09:12,380 - INFO -   Model precise - RMSE: 2.990358
# 2025-06-05 15:09:12,382 - INFO -   Prediction statistics: min=-7.1663, max=98.3095, mean=3.1853
# 2025-06-05 15:09:12,383 - INFO -   ---------------------
# 2025-06-05 15:09:12,384 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:09:12,384 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:12,385 - INFO -   Starting training...
# 2025-06-05 15:09:14,833 - INFO -   Training completed successfully in 2.45 seconds
# 2025-06-05 15:09:14,833 - INFO -   Best iteration: 1500
# 2025-06-05 15:09:14,975 - INFO -   Model feature_selective - RMSE: 2.967940
# 2025-06-05 15:09:14,975 - INFO -   Prediction statistics: min=-4.5880, max=96.7336, mean=3.1523
# 2025-06-05 15:09:14,979 - INFO -   ---------------------
# 2025-06-05 15:09:14,979 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:09:14,980 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:14,980 - INFO -   Starting training...
# 2025-06-05 15:09:16,478 - INFO -   Training completed successfully in 1.50 seconds
# 2025-06-05 15:09:16,490 - INFO -   Best iteration: 1000
# 2025-06-05 15:09:16,554 - INFO -   Model robust - RMSE: 3.134826
# 2025-06-05 15:09:16,570 - INFO -   Prediction statistics: min=-6.6633, max=99.6455, mean=3.1465
# 2025-06-05 15:09:16,570 - INFO -   ---------------------
# 2025-06-05 15:09:16,570 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:09:16,570 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:09:16,574 - INFO -   Starting training...
# 2025-06-05 15:09:25,588 - INFO -   Training completed successfully in 9.02 seconds
# 2025-06-05 15:09:25,592 - INFO -   Best iteration: 2999
# 2025-06-05 15:09:26,142 - INFO -   Model deep_forest - RMSE: 2.963862
# 2025-06-05 15:09:26,142 - INFO -   Prediction statistics: min=-2.1783, max=98.7714, mean=3.1851
# 2025-06-05 15:09:26,142 - INFO -   ---------------------
# 2025-06-05 15:09:26,142 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:09:26,142 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:26,142 - INFO -   Starting training...
# 2025-06-05 15:09:27,294 - INFO -   Training completed successfully in 1.15 seconds
# 2025-06-05 15:09:27,294 - INFO -   Best iteration: 1200
# 2025-06-05 15:09:27,369 - INFO -   Model highly_regularized - RMSE: 3.421036
# 2025-06-05 15:09:27,369 - INFO -   Prediction statistics: min=-7.4801, max=93.8970, mean=3.1326
# 2025-06-05 15:09:27,372 - INFO -   ---------------------
# 2025-06-05 15:09:27,373 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:09:27,373 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:09:27,375 - INFO -   Starting training...
# 2025-06-05 15:09:28,378 - INFO -   Training completed successfully in 1.01 seconds
# 2025-06-05 15:09:28,378 - INFO -   Best iteration: 491
# 2025-06-05 15:09:28,414 - INFO -   Model fast_learner - RMSE: 2.981904
# 2025-06-05 15:09:28,414 - INFO -   Prediction statistics: min=-12.5929, max=97.0981, mean=3.1564
# 2025-06-05 15:09:28,414 - INFO -   ---------------------
# 2025-06-05 15:09:28,426 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:09:28,426 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:09:28,426 - INFO -   Starting training...
# 2025-06-05 15:09:32,331 - INFO -   Training completed successfully in 3.92 seconds
# 2025-06-05 15:09:32,331 - INFO -   Best iteration: 1786
# 2025-06-05 15:09:32,508 - INFO -   Model balanced - RMSE: 3.248103
# 2025-06-05 15:09:32,508 - INFO -   Prediction statistics: min=-3.2174, max=94.1520, mean=3.1726
# 2025-06-05 15:09:32,508 - INFO -   ---------------------
# 2025-06-05 15:09:32,508 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:09:49,602 - INFO -   Optimal weights found: 0.0000, 0.3031, 0.0000, 0.4195, 0.0000, 0.2774, 0.0000
# 2025-06-05 15:09:49,602 - INFO -   Bayesian optimization - RMSE: 2.922939
# 2025-06-05 15:09:49,618 - INFO -   Final prediction statistics: min=-5.3533, max=97.6896, mean=3.1672
# 2025-06-05 15:09:49,621 - INFO -   RMSE with equal weights: 3.027982
# 2025-06-05 15:09:49,623 - INFO -   Improvement: 3.47%
# 2025-06-05 15:09:49,952 - INFO - Fold 1 completed in 41.66 seconds
# 2025-06-05 15:09:49,969 - INFO - =====================
# 2025-06-05 15:09:49,969 - INFO - Fold 2/5 for Model_1_Data1
# 2025-06-05 15:09:49,969 - INFO - Train: 11986 samples, Validation: 2997 samples
# 2025-06-05 15:09:49,969 - INFO - y_train statistics: min=0.0000, max=110.8552, mean=3.3748
# 2025-06-05 15:09:49,969 - INFO - y_val statistics: min=0.0000, max=88.1238, mean=3.3569
# 2025-06-05 15:09:49,969 - INFO -   ---------------------
# 2025-06-05 15:09:49,985 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:09:49,985 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:49,985 - INFO -   Starting training...
# 2025-06-05 15:09:53,619 - INFO -   Training completed successfully in 3.65 seconds
# 2025-06-05 15:09:53,621 - INFO -   Best iteration: 2000
# 2025-06-05 15:09:53,791 - INFO -   Model precise - RMSE: 3.232971
# 2025-06-05 15:09:53,791 - INFO -   Prediction statistics: min=-8.1052, max=86.4830, mean=3.4489
# 2025-06-05 15:09:53,793 - INFO -   ---------------------
# 2025-06-05 15:09:53,793 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:09:53,795 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:53,797 - INFO -   Starting training...
# 2025-06-05 15:09:56,025 - INFO -   Training completed successfully in 2.23 seconds
# 2025-06-05 15:09:56,025 - INFO -   Best iteration: 1500
# 2025-06-05 15:09:56,179 - INFO -   Model feature_selective - RMSE: 3.323406
# 2025-06-05 15:09:56,179 - INFO -   Prediction statistics: min=-3.9522, max=85.9740, mean=3.4540
# 2025-06-05 15:09:56,179 - INFO -   ---------------------
# 2025-06-05 15:09:56,179 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:09:56,184 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:09:56,184 - INFO -   Starting training...
# 2025-06-05 15:09:57,647 - INFO -   Training completed successfully in 1.47 seconds
# 2025-06-05 15:09:57,647 - INFO -   Best iteration: 1000
# 2025-06-05 15:09:57,729 - INFO -   Model robust - RMSE: 3.364114
# 2025-06-05 15:09:57,729 - INFO -   Prediction statistics: min=-15.9237, max=89.0465, mean=3.4148
# 2025-06-05 15:09:57,731 - INFO -   ---------------------
# 2025-06-05 15:09:57,731 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:09:57,731 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:09:57,735 - INFO -   Starting training...
# 2025-06-05 15:10:06,550 - INFO -   Training completed successfully in 8.82 seconds
# 2025-06-05 15:10:06,552 - INFO -   Best iteration: 2999
# 2025-06-05 15:10:07,096 - INFO -   Model deep_forest - RMSE: 3.271598
# 2025-06-05 15:10:07,098 - INFO -   Prediction statistics: min=-2.9177, max=84.3746, mean=3.4468
# 2025-06-05 15:10:07,100 - INFO -   ---------------------
# 2025-06-05 15:10:07,100 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:10:07,100 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:10:07,102 - INFO -   Starting training...
# 2025-06-05 15:10:08,273 - INFO -   Training completed successfully in 1.17 seconds
# 2025-06-05 15:10:08,273 - INFO -   Best iteration: 1200
# 2025-06-05 15:10:08,352 - INFO -   Model highly_regularized - RMSE: 3.765147
# 2025-06-05 15:10:08,352 - INFO -   Prediction statistics: min=-7.0492, max=86.0741, mean=3.4518
# 2025-06-05 15:10:08,354 - INFO -   ---------------------
# 2025-06-05 15:10:08,354 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:10:08,354 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:10:08,356 - INFO -   Starting training...
# 2025-06-05 15:10:09,255 - INFO -   Training completed successfully in 0.90 seconds
# 2025-06-05 15:10:09,255 - INFO -   Best iteration: 405
# 2025-06-05 15:10:09,277 - INFO -   Model fast_learner - RMSE: 3.245186
# 2025-06-05 15:10:09,277 - INFO -   Prediction statistics: min=-6.4572, max=86.7221, mean=3.4537
# 2025-06-05 15:10:09,293 - INFO -   ---------------------
# 2025-06-05 15:10:09,293 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:10:09,293 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:10:09,295 - INFO -   Starting training...
# 2025-06-05 15:10:13,790 - INFO -   Training completed successfully in 4.50 seconds
# 2025-06-05 15:10:13,792 - INFO -   Best iteration: 1800
# 2025-06-05 15:10:13,983 - INFO -   Model balanced - RMSE: 3.341329
# 2025-06-05 15:10:13,983 - INFO -   Prediction statistics: min=-6.2727, max=85.8244, mean=3.4527
# 2025-06-05 15:10:13,985 - INFO -   ---------------------
# 2025-06-05 15:10:13,985 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:10:27,901 - INFO -   Optimal weights found: 0.3749, 0.0000, 0.0000, 0.2437, 0.0000, 0.3814, 0.0000
# 2025-06-05 15:10:27,901 - INFO -   Bayesian optimization - RMSE: 3.198232
# 2025-06-05 15:10:27,917 - INFO -   Final prediction statistics: min=-4.8740, max=86.0499, mean=3.4502
# 2025-06-05 15:10:27,920 - INFO -   RMSE with equal weights: 3.278383
# 2025-06-05 15:10:27,920 - INFO -   Improvement: 2.44%
# 2025-06-05 15:10:27,920 - INFO - Fold 2 completed in 37.95 seconds
# 2025-06-05 15:10:27,920 - INFO - =====================
# 2025-06-05 15:10:27,920 - INFO - Fold 3/5 for Model_1_Data1
# 2025-06-05 15:10:27,920 - INFO - Train: 11986 samples, Validation: 2997 samples
# 2025-06-05 15:10:27,934 - INFO - y_train statistics: min=0.0000, max=110.8552, mean=3.3432
# 2025-06-05 15:10:27,934 - INFO - y_val statistics: min=0.0000, max=97.6439, mean=3.4834
# 2025-06-05 15:10:27,934 - INFO -   ---------------------
# 2025-06-05 15:10:27,934 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:10:27,934 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:10:27,934 - INFO -   Starting training...
# 2025-06-05 15:10:31,778 - INFO -   Training completed successfully in 3.84 seconds
# 2025-06-05 15:10:31,778 - INFO -   Best iteration: 2000
# 2025-06-05 15:10:31,952 - INFO -   Model precise - RMSE: 3.106576
# 2025-06-05 15:10:31,952 - INFO -   Prediction statistics: min=-5.4099, max=92.1115, mean=3.3970
# 2025-06-05 15:10:31,952 - INFO -   ---------------------
# 2025-06-05 15:10:31,952 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:10:31,952 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:10:31,952 - INFO -   Starting training...
# 2025-06-05 15:10:34,178 - INFO -   Training completed successfully in 2.23 seconds
# 2025-06-05 15:10:34,178 - INFO -   Best iteration: 1500
# 2025-06-05 15:10:34,313 - INFO -   Model feature_selective - RMSE: 3.174973
# 2025-06-05 15:10:34,313 - INFO -   Prediction statistics: min=-13.4554, max=91.4153, mean=3.4052
# 2025-06-05 15:10:34,313 - INFO -   ---------------------
# 2025-06-05 15:10:34,313 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:10:34,313 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:10:34,313 - INFO -   Starting training...
# 2025-06-05 15:10:35,759 - INFO -   Training completed successfully in 1.45 seconds
# 2025-06-05 15:10:35,759 - INFO -   Best iteration: 1000
# 2025-06-05 15:10:35,839 - INFO -   Model robust - RMSE: 3.155017
# 2025-06-05 15:10:35,839 - INFO -   Prediction statistics: min=-6.7781, max=98.6138, mean=3.3777
# 2025-06-05 15:10:35,839 - INFO -   ---------------------
# 2025-06-05 15:10:35,839 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:10:35,839 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:10:35,850 - INFO -   Starting training...
# 2025-06-05 15:10:44,621 - INFO -   Training completed successfully in 8.78 seconds
# 2025-06-05 15:10:44,621 - INFO -   Best iteration: 3000
# 2025-06-05 15:10:45,114 - INFO -   Model deep_forest - RMSE: 2.991523
# 2025-06-05 15:10:45,130 - INFO -   Prediction statistics: min=-5.0444, max=92.3211, mean=3.4158
# 2025-06-05 15:10:45,130 - INFO -   ---------------------
# 2025-06-05 15:10:45,132 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:10:45,132 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:10:45,132 - INFO -   Starting training...
# 2025-06-05 15:10:46,253 - INFO -   Training completed successfully in 1.12 seconds
# 2025-06-05 15:10:46,253 - INFO -   Best iteration: 1200
# 2025-06-05 15:10:46,324 - INFO -   Model highly_regularized - RMSE: 3.472979
# 2025-06-05 15:10:46,324 - INFO -   Prediction statistics: min=-5.7313, max=89.0772, mean=3.3660
# 2025-06-05 15:10:46,324 - INFO -   ---------------------
# 2025-06-05 15:10:46,329 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:10:46,329 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:10:46,329 - INFO -   Starting training...
# 2025-06-05 15:10:47,725 - INFO -   Training completed successfully in 1.40 seconds
# 2025-06-05 15:10:47,725 - INFO -   Best iteration: 792
# 2025-06-05 15:10:47,789 - INFO -   Model fast_learner - RMSE: 2.887139
# 2025-06-05 15:10:47,789 - INFO -   Prediction statistics: min=-2.2988, max=89.7798, mean=3.3978
# 2025-06-05 15:10:47,805 - INFO -   ---------------------
# 2025-06-05 15:10:47,805 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:10:47,805 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:10:47,806 - INFO -   Starting training...
# 2025-06-05 15:10:51,753 - INFO -   Training completed successfully in 3.95 seconds
# 2025-06-05 15:10:51,753 - INFO -   Best iteration: 1788
# 2025-06-05 15:10:51,927 - INFO -   Model balanced - RMSE: 3.247743
# 2025-06-05 15:10:51,927 - INFO -   Prediction statistics: min=-6.5629, max=88.8647, mean=3.3921
# 2025-06-05 15:10:51,927 - INFO -   ---------------------
# 2025-06-05 15:10:51,927 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:11:06,115 - INFO -   Optimal weights found: 0.0000, 0.0000, 0.0000, 0.2719, 0.0000, 0.7281, 0.0000
# 2025-06-05 15:11:06,115 - INFO -   Bayesian optimization - RMSE: 2.869842
# 2025-06-05 15:11:06,115 - INFO -   Final prediction statistics: min=-3.0454, max=90.4708, mean=3.4027
# 2025-06-05 15:11:06,115 - INFO -   RMSE with equal weights: 3.054570
# 2025-06-05 15:11:06,115 - INFO -   Improvement: 6.05%
# 2025-06-05 15:11:06,115 - INFO - Fold 3 completed in 38.19 seconds
# 2025-06-05 15:11:06,115 - INFO - =====================
# 2025-06-05 15:11:06,115 - INFO - Fold 4/5 for Model_1_Data1
# 2025-06-05 15:11:06,115 - INFO - Train: 11987 samples, Validation: 2996 samples
# 2025-06-05 15:11:06,131 - INFO - y_train statistics: min=0.0000, max=104.8954, mean=3.3730
# 2025-06-05 15:11:06,131 - INFO - y_val statistics: min=0.0000, max=110.8552, mean=3.3642
# 2025-06-05 15:11:06,131 - INFO -   ---------------------
# 2025-06-05 15:11:06,131 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:11:06,137 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:06,137 - INFO -   Starting training...
# 2025-06-05 15:11:09,556 - INFO -   Training completed successfully in 3.43 seconds
# 2025-06-05 15:11:09,556 - INFO -   Best iteration: 2000
# 2025-06-05 15:11:09,731 - INFO -   Model precise - RMSE: 3.813608
# 2025-06-05 15:11:09,731 - INFO -   Prediction statistics: min=-13.1168, max=101.0352, mean=3.3494
# 2025-06-05 15:11:09,731 - INFO -   ---------------------
# 2025-06-05 15:11:09,731 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:11:09,731 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:09,731 - INFO -   Starting training...
# 2025-06-05 15:11:11,956 - INFO -   Training completed successfully in 2.23 seconds
# 2025-06-05 15:11:11,956 - INFO -   Best iteration: 1499
# 2025-06-05 15:11:12,100 - INFO -   Model feature_selective - RMSE: 3.736450
# 2025-06-05 15:11:12,100 - INFO -   Prediction statistics: min=-11.9517, max=99.8033, mean=3.3660
# 2025-06-05 15:11:12,109 - INFO -   ---------------------
# 2025-06-05 15:11:12,110 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:11:12,111 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:12,111 - INFO -   Starting training...
# 2025-06-05 15:11:12,908 - INFO -   Training completed successfully in 0.80 seconds
# 2025-06-05 15:11:12,908 - INFO -   Best iteration: 450
# 2025-06-05 15:11:12,946 - INFO -   Model robust - RMSE: 3.911773
# 2025-06-05 15:11:12,946 - INFO -   Prediction statistics: min=-5.6099, max=93.8021, mean=3.3509
# 2025-06-05 15:11:12,946 - INFO -   ---------------------
# 2025-06-05 15:11:12,957 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:11:12,957 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:11:12,957 - INFO -   Starting training...
# 2025-06-05 15:11:21,653 - INFO -   Training completed successfully in 8.71 seconds
# 2025-06-05 15:11:21,653 - INFO -   Best iteration: 2997
# 2025-06-05 15:11:22,148 - INFO -   Model deep_forest - RMSE: 3.856789
# 2025-06-05 15:11:22,148 - INFO -   Prediction statistics: min=-8.8638, max=100.8645, mean=3.3830
# 2025-06-05 15:11:22,148 - INFO -   ---------------------
# 2025-06-05 15:11:22,148 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:11:22,162 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:22,162 - INFO -   Starting training...
# 2025-06-05 15:11:23,292 - INFO -   Training completed successfully in 1.14 seconds
# 2025-06-05 15:11:23,296 - INFO -   Best iteration: 1193
# 2025-06-05 15:11:23,375 - INFO -   Model highly_regularized - RMSE: 4.194022
# 2025-06-05 15:11:23,375 - INFO -   Prediction statistics: min=-5.1242, max=100.8272, mean=3.3833
# 2025-06-05 15:11:23,375 - INFO -   ---------------------
# 2025-06-05 15:11:23,375 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:11:23,375 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:11:23,390 - INFO -   Starting training...
# 2025-06-05 15:11:24,688 - INFO -   Training completed successfully in 1.31 seconds
# 2025-06-05 15:11:24,690 - INFO -   Best iteration: 673
# 2025-06-05 15:11:24,741 - INFO -   Model fast_learner - RMSE: 3.666498
# 2025-06-05 15:11:24,741 - INFO -   Prediction statistics: min=-6.8183, max=100.9686, mean=3.3494
# 2025-06-05 15:11:24,741 - INFO -   ---------------------
# 2025-06-05 15:11:24,741 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:11:24,741 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:11:24,741 - INFO -   Starting training...
# 2025-06-05 15:11:28,582 - INFO -   Training completed successfully in 3.84 seconds
# 2025-06-05 15:11:28,582 - INFO -   Best iteration: 1800
# 2025-06-05 15:11:28,770 - INFO -   Model balanced - RMSE: 3.818826
# 2025-06-05 15:11:28,770 - INFO -   Prediction statistics: min=-6.1566, max=94.3605, mean=3.3821
# 2025-06-05 15:11:28,770 - INFO -   ---------------------
# 2025-06-05 15:11:28,773 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:11:43,751 - INFO -   Optimal weights found: 0.0000, 0.2867, 0.0000, 0.0000, 0.0000, 0.7133, 0.0000
# 2025-06-05 15:11:43,753 - INFO -   Bayesian optimization - RMSE: 3.652814
# 2025-06-05 15:11:43,755 - INFO -   Final prediction statistics: min=-7.0201, max=100.6345, mean=3.3542
# 2025-06-05 15:11:43,755 - INFO -   RMSE with equal weights: 3.769657
# 2025-06-05 15:11:43,757 - INFO -   Improvement: 3.10%
# 2025-06-05 15:11:43,757 - INFO - Fold 4 completed in 37.64 seconds
# 2025-06-05 15:11:43,760 - INFO - =====================
# 2025-06-05 15:11:43,760 - INFO - Fold 5/5 for Model_1_Data1
# 2025-06-05 15:11:43,760 - INFO - Train: 11987 samples, Validation: 2996 samples
# 2025-06-05 15:11:43,767 - INFO - y_train statistics: min=0.0000, max=110.8552, mean=3.3681
# 2025-06-05 15:11:43,767 - INFO - y_val statistics: min=0.0000, max=104.8954, mean=3.3838
# 2025-06-05 15:11:43,767 - INFO -   ---------------------
# 2025-06-05 15:11:43,767 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:11:43,767 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:43,767 - INFO -   Starting training...
# 2025-06-05 15:11:47,231 - INFO -   Training completed successfully in 3.46 seconds
# 2025-06-05 15:11:47,231 - INFO -   Best iteration: 1997
# 2025-06-05 15:11:47,385 - INFO -   Model precise - RMSE: 3.463282
# 2025-06-05 15:11:47,385 - INFO -   Prediction statistics: min=-7.0667, max=119.2185, mean=3.4805
# 2025-06-05 15:11:47,385 - INFO -   ---------------------
# 2025-06-05 15:11:47,385 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:11:47,390 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:47,390 - INFO -   Starting training...
# 2025-06-05 15:11:49,625 - INFO -   Training completed successfully in 2.24 seconds
# 2025-06-05 15:11:49,627 - INFO -   Best iteration: 1500
# 2025-06-05 15:11:49,762 - INFO -   Model feature_selective - RMSE: 3.349034
# 2025-06-05 15:11:49,762 - INFO -   Prediction statistics: min=-4.5920, max=103.4639, mean=3.4684
# 2025-06-05 15:11:49,762 - INFO -   ---------------------
# 2025-06-05 15:11:49,762 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:11:49,762 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:49,762 - INFO -   Starting training...
# 2025-06-05 15:11:50,422 - INFO -   Training completed successfully in 0.66 seconds
# 2025-06-05 15:11:50,424 - INFO -   Best iteration: 381
# 2025-06-05 15:11:50,465 - INFO -   Model robust - RMSE: 3.661181
# 2025-06-05 15:11:50,465 - INFO -   Prediction statistics: min=-2.0894, max=103.7403, mean=3.4979
# 2025-06-05 15:11:50,476 - INFO -   ---------------------
# 2025-06-05 15:11:50,476 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:11:50,476 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:11:50,480 - INFO -   Starting training...
# 2025-06-05 15:11:53,688 - INFO -   Training completed successfully in 3.21 seconds
# 2025-06-05 15:11:53,688 - INFO -   Best iteration: 971
# 2025-06-05 15:11:53,809 - INFO -   Model deep_forest - RMSE: 3.679206
# 2025-06-05 15:11:53,811 - INFO -   Prediction statistics: min=-2.3816, max=88.5685, mean=3.4929
# 2025-06-05 15:11:53,813 - INFO -   ---------------------
# 2025-06-05 15:11:53,813 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:11:53,813 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:11:53,815 - INFO -   Starting training...
# 2025-06-05 15:11:55,013 - INFO -   Training completed successfully in 1.20 seconds
# 2025-06-05 15:11:55,026 - INFO -   Best iteration: 1194
# 2025-06-05 15:11:55,124 - INFO -   Model highly_regularized - RMSE: 3.622807
# 2025-06-05 15:11:55,124 - INFO -   Prediction statistics: min=-3.7960, max=115.4526, mean=3.5312
# 2025-06-05 15:11:55,131 - INFO -   ---------------------
# 2025-06-05 15:11:55,131 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:11:55,131 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:11:55,131 - INFO -   Starting training...
# 2025-06-05 15:11:56,325 - INFO -   Training completed successfully in 1.19 seconds
# 2025-06-05 15:11:56,325 - INFO -   Best iteration: 632
# 2025-06-05 15:11:56,377 - INFO -   Model fast_learner - RMSE: 3.459064
# 2025-06-05 15:11:56,379 - INFO -   Prediction statistics: min=-6.4526, max=113.7126, mean=3.4858
# 2025-06-05 15:11:56,379 - INFO -   ---------------------
# 2025-06-05 15:11:56,381 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:11:56,381 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:11:56,383 - INFO -   Starting training...
# 2025-06-05 15:12:00,056 - INFO -   Training completed successfully in 3.68 seconds
# 2025-06-05 15:12:00,058 - INFO -   Best iteration: 1800
# 2025-06-05 15:12:00,233 - INFO -   Model balanced - RMSE: 3.430729
# 2025-06-05 15:12:00,235 - INFO -   Prediction statistics: min=-4.2114, max=107.5576, mean=3.4998
# 2025-06-05 15:12:00,235 - INFO -   ---------------------
# 2025-06-05 15:12:00,237 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:12:17,079 - INFO -   Optimal weights found: 0.0000, 0.6831, 0.0000, 0.0000, 0.0000, 0.0576, 0.2593
# 2025-06-05 15:12:17,079 - INFO -   Bayesian optimization - RMSE: 3.334257
# 2025-06-05 15:12:17,079 - INFO -   Final prediction statistics: min=-4.2873, max=105.1154, mean=3.4775
# 2025-06-05 15:12:17,079 - INFO -   RMSE with equal weights: 3.419502
# 2025-06-05 15:12:17,079 - INFO -   Improvement: 2.49%
# 2025-06-05 15:12:17,079 - INFO - Fold 5 completed in 33.32 seconds
# 2025-06-05 15:12:17,079 - INFO - =====================
# 2025-06-05 15:12:17,090 - INFO - CV RMSE for Model_1_Data1 (with optimal weights): 3.195617 ± 0.285916
# 2025-06-05 15:12:17,091 - INFO - OOF RMSE for Model_1_Data1 (with optimal weights): 3.208342
# 2025-06-05 15:12:17,091 - INFO - OOF prediction statistics: min=-7.0201, max=105.1154, mean=3.3704
# 2025-06-05 15:12:17,091 - INFO - OOF RMSE for base model precise: 3.334116
# 2025-06-05 15:12:17,095 - INFO - OOF RMSE for base model feature_selective: 3.319946
# 2025-06-05 15:12:17,098 - INFO - OOF RMSE for base model robust: 3.458414
# 2025-06-05 15:12:17,098 - INFO - OOF RMSE for base model deep_forest: 3.371840
# 2025-06-05 15:12:17,098 - INFO - OOF RMSE for base model highly_regularized: 3.705533
# 2025-06-05 15:12:17,098 - INFO - OOF RMSE for base model fast_learner: 3.260843
# 2025-06-05 15:12:17,098 - INFO - OOF RMSE for base model balanced: 3.423882
# 2025-06-05 15:12:17,098 - INFO - Average optimal weights across all folds: 0.0750, 0.2546, 0.0000, 0.1870, 0.0000, 0.4315, 0.0519
# 2025-06-05 15:12:17,098 - INFO - Complete training finished in 188.84 seconds (3.15 minutes)
# 2025-06-05 15:12:17,111 - INFO - ========== END TRAINING Model_1_Data1 ==========
# 2025-06-05 15:12:17,111 - INFO - Training Model 2 (Data2) => 5 folds
# 2025-06-05 15:12:17,111 - INFO - ========== START TRAINING Model_2_Data2 ==========
# 2025-06-05 15:12:17,111 - INFO - Training Model_2_Data2 with stacking of 7 LGBMs (CV 5-folds)...
# 2025-06-05 15:12:17,111 - INFO - Input data: 11313 samples with 86 columns
# 2025-06-05 15:12:17,111 - INFO - Detected target column: kwh_sum
# 2025-06-05 15:12:17,143 - INFO - Total of 31 columns excluded from training
# 2025-06-05 15:12:17,143 - INFO - Prepared dataset: X shape=(11313, 56), y shape=(11313,)
# 2025-06-05 15:12:17,143 - INFO - Target statistics: min=0.0000, max=122.5230, mean=2.0561, median=0.0706
# 2025-06-05 15:12:17,143 - INFO - Detected categorical features: Source, season
# 2025-06-05 15:12:17,159 - INFO - Configuration of 7 LightGBM models with different parameters
# 2025-06-05 15:12:17,159 - INFO - Starting training with 5-fold cross-validation
# 2025-06-05 15:12:17,159 - INFO - =====================
# 2025-06-05 15:12:17,159 - INFO - Fold 1/5 for Model_2_Data2
# 2025-06-05 15:12:17,159 - INFO - Train: 9050 samples, Validation: 2263 samples
# 2025-06-05 15:12:17,174 - INFO - y_train statistics: min=0.0000, max=122.5230, mean=2.0558
# 2025-06-05 15:12:17,174 - INFO - y_val statistics: min=0.0000, max=119.8869, mean=2.0574
# 2025-06-05 15:12:17,174 - INFO -   ---------------------
# 2025-06-05 15:12:17,174 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:12:17,174 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:17,174 - INFO -   Starting training...
# 2025-06-05 15:12:20,374 - INFO -   Training completed successfully in 3.20 seconds
# 2025-06-05 15:12:20,375 - INFO -   Best iteration: 2000
# 2025-06-05 15:12:20,543 - INFO -   Model precise - RMSE: 3.014428
# 2025-06-05 15:12:20,544 - INFO -   Prediction statistics: min=-6.0456, max=85.1051, mean=2.0118
# 2025-06-05 15:12:20,545 - INFO -   ---------------------
# 2025-06-05 15:12:20,546 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:12:20,547 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:20,549 - INFO -   Starting training...
# 2025-06-05 15:12:22,477 - INFO -   Training completed successfully in 1.93 seconds
# 2025-06-05 15:12:22,478 - INFO -   Best iteration: 1499
# 2025-06-05 15:12:22,582 - INFO -   Model feature_selective - RMSE: 2.944008
# 2025-06-05 15:12:22,583 - INFO -   Prediction statistics: min=-6.4985, max=86.0151, mean=2.0158
# 2025-06-05 15:12:22,584 - INFO -   ---------------------
# 2025-06-05 15:12:22,586 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:12:22,587 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:22,588 - INFO -   Starting training...
# 2025-06-05 15:12:23,839 - INFO -   Training completed successfully in 1.25 seconds
# 2025-06-05 15:12:23,840 - INFO -   Best iteration: 964
# 2025-06-05 15:12:23,910 - INFO -   Model robust - RMSE: 2.988816
# 2025-06-05 15:12:23,911 - INFO -   Prediction statistics: min=-4.2876, max=87.8909, mean=2.0055
# 2025-06-05 15:12:23,912 - INFO -   ---------------------
# 2025-06-05 15:12:23,913 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:12:23,915 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:12:23,915 - INFO -   Starting training...
# 2025-06-05 15:12:31,273 - INFO -   Training completed successfully in 7.36 seconds
# 2025-06-05 15:12:31,275 - INFO -   Best iteration: 3000
# 2025-06-05 15:12:31,738 - INFO -   Model deep_forest - RMSE: 3.040494
# 2025-06-05 15:12:31,740 - INFO -   Prediction statistics: min=-6.6290, max=83.7149, mean=2.0256
# 2025-06-05 15:12:31,740 - INFO -   ---------------------
# 2025-06-05 15:12:31,740 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:12:31,740 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:31,740 - INFO -   Starting training...
# 2025-06-05 15:12:32,691 - INFO -   Training completed successfully in 0.95 seconds
# 2025-06-05 15:12:32,693 - INFO -   Best iteration: 1200
# 2025-06-05 15:12:32,745 - INFO -   Model highly_regularized - RMSE: 3.275622
# 2025-06-05 15:12:32,747 - INFO -   Prediction statistics: min=-2.2547, max=81.3102, mean=2.0110
# 2025-06-05 15:12:32,747 - INFO -   ---------------------
# 2025-06-05 15:12:32,747 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:12:32,749 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:12:32,751 - INFO -   Starting training...
# 2025-06-05 15:12:33,892 - INFO -   Training completed successfully in 1.15 seconds
# 2025-06-05 15:12:33,892 - INFO -   Best iteration: 799
# 2025-06-05 15:12:33,943 - INFO -   Model fast_learner - RMSE: 2.867792
# 2025-06-05 15:12:33,945 - INFO -   Prediction statistics: min=-8.4953, max=88.6610, mean=2.0183
# 2025-06-05 15:12:33,945 - INFO -   ---------------------
# 2025-06-05 15:12:33,948 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:12:33,948 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:12:33,948 - INFO -   Starting training...
# 2025-06-05 15:12:37,101 - INFO -   Training completed successfully in 3.16 seconds
# 2025-06-05 15:12:37,101 - INFO -   Best iteration: 1800
# 2025-06-05 15:12:37,248 - INFO -   Model balanced - RMSE: 3.027314
# 2025-06-05 15:12:37,250 - INFO -   Prediction statistics: min=-3.9197, max=88.3657, mean=2.0186
# 2025-06-05 15:12:37,250 - INFO -   ---------------------
# 2025-06-05 15:12:37,250 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:12:53,056 - INFO -   Optimal weights found: 0.0000, 0.1292, 0.0000, 0.0000, 0.0000, 0.8708, 0.0000
# 2025-06-05 15:12:53,056 - INFO -   Bayesian optimization - RMSE: 2.866479
# 2025-06-05 15:12:53,056 - INFO -   Final prediction statistics: min=-8.2373, max=88.3192, mean=2.0180
# 2025-06-05 15:12:53,062 - INFO -   RMSE with equal weights: 2.968889
# 2025-06-05 15:12:53,063 - INFO -   Improvement: 3.45%
# 2025-06-05 15:12:53,541 - INFO - Fold 1 completed in 36.38 seconds
# 2025-06-05 15:12:53,541 - INFO - =====================
# 2025-06-05 15:12:53,541 - INFO - Fold 2/5 for Model_2_Data2
# 2025-06-05 15:12:53,554 - INFO - Train: 9050 samples, Validation: 2263 samples
# 2025-06-05 15:12:53,566 - INFO - y_train statistics: min=0.0000, max=122.5230, mean=2.0408
# 2025-06-05 15:12:53,566 - INFO - y_val statistics: min=0.0000, max=77.5092, mean=2.1173
# 2025-06-05 15:12:53,566 - INFO -   ---------------------
# 2025-06-05 15:12:53,566 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:12:53,566 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:53,573 - INFO -   Starting training...
# 2025-06-05 15:12:56,473 - INFO -   Training completed successfully in 2.91 seconds
# 2025-06-05 15:12:56,488 - INFO -   Best iteration: 2000
# 2025-06-05 15:12:56,623 - INFO -   Model precise - RMSE: 3.291937
# 2025-06-05 15:12:56,623 - INFO -   Prediction statistics: min=-4.0217, max=61.9523, mean=2.0199
# 2025-06-05 15:12:56,623 - INFO -   ---------------------
# 2025-06-05 15:12:56,623 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:12:56,623 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:56,623 - INFO -   Starting training...
# 2025-06-05 15:12:58,462 - INFO -   Training completed successfully in 1.84 seconds
# 2025-06-05 15:12:58,463 - INFO -   Best iteration: 1500
# 2025-06-05 15:12:58,561 - INFO -   Model feature_selective - RMSE: 3.250157
# 2025-06-05 15:12:58,563 - INFO -   Prediction statistics: min=-3.9888, max=59.4912, mean=2.0239
# 2025-06-05 15:12:58,563 - INFO -   ---------------------
# 2025-06-05 15:12:58,565 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:12:58,565 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:12:58,566 - INFO -   Starting training...
# 2025-06-05 15:12:59,650 - INFO -   Training completed successfully in 1.09 seconds
# 2025-06-05 15:12:59,652 - INFO -   Best iteration: 1000
# ...
# 2025-06-05 15:17:36,095 - INFO -   Optimal weights found: 0.2858, 0.0000, 0.0000, 0.0000, 0.0000, 0.7142, 0.0000
# 2025-06-05 15:17:36,095 - INFO -   Bayesian optimization - RMSE: 2.812751
# 2025-06-05 15:17:36,095 - INFO -   Final prediction statistics: min=-7.0197, max=84.0739, mean=2.6745
# 2025-06-05 15:17:36,100 - INFO -   RMSE with equal weights: 2.966017
# 2025-06-05 15:17:36,100 - INFO -   Improvement: 5.17%
# 2025-06-05 15:17:36,100 - INFO - Fold 3 completed in 48.78 seconds
# 2025-06-05 15:17:36,100 - INFO - =====================
# 2025-06-05 15:17:36,100 - INFO - Fold 4/5 for Model_4_Data4
# 2025-06-05 15:17:36,100 - INFO - Train: 21039 samples, Validation: 5259 samples
# 2025-06-05 15:17:36,116 - INFO - y_train statistics: min=0.0000, max=122.5230, mean=2.8076
# 2025-06-05 15:17:36,116 - INFO - y_val statistics: min=0.0000, max=115.8641, mean=2.7958
# 2025-06-05 15:17:36,116 - INFO -   ---------------------
# 2025-06-05 15:17:36,116 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:17:36,116 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:17:36,116 - INFO -   Starting training...
# 2025-06-05 15:17:41,022 - INFO -   Training completed successfully in 4.91 seconds
# 2025-06-05 15:17:41,024 - INFO -   Best iteration: 2000
# 2025-06-05 15:17:41,287 - INFO -   Model precise - RMSE: 3.321760
# 2025-06-05 15:17:41,287 - INFO -   Prediction statistics: min=-3.6253, max=82.4982, mean=2.7998
# 2025-06-05 15:17:41,289 - INFO -   ---------------------
# 2025-06-05 15:17:41,289 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:17:41,289 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:17:41,291 - INFO -   Starting training...
# 2025-06-05 15:17:44,415 - INFO -   Training completed successfully in 3.13 seconds
# 2025-06-05 15:17:44,417 - INFO -   Best iteration: 1500
# 2025-06-05 15:17:44,717 - INFO -   Model feature_selective - RMSE: 3.323485
# 2025-06-05 15:17:44,717 - INFO -   Prediction statistics: min=-6.4520, max=84.3676, mean=2.7941
# 2025-06-05 15:17:44,719 - INFO -   ---------------------
# 2025-06-05 15:17:44,719 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:17:44,719 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:17:44,722 - INFO -   Starting training...
# 2025-06-05 15:17:46,929 - INFO -   Training completed successfully in 2.21 seconds
# 2025-06-05 15:17:46,931 - INFO -   Best iteration: 1000
# 2025-06-05 15:17:47,071 - INFO -   Model robust - RMSE: 3.448926
# 2025-06-05 15:17:47,073 - INFO -   Prediction statistics: min=-6.2076, max=86.5958, mean=2.8164
# 2025-06-05 15:17:47,073 - INFO -   ---------------------
# 2025-06-05 15:17:47,075 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:17:47,076 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:17:47,076 - INFO -   Starting training...
# 2025-06-05 15:17:58,701 - INFO -   Training completed successfully in 11.63 seconds
# 2025-06-05 15:17:58,701 - INFO -   Best iteration: 3000
# 2025-06-05 15:17:59,549 - INFO -   Model deep_forest - RMSE: 3.199100
# 2025-06-05 15:17:59,551 - INFO -   Prediction statistics: min=-4.2443, max=86.5245, mean=2.7972
# 2025-06-05 15:17:59,551 - INFO -   ---------------------
# 2025-06-05 15:17:59,553 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:17:59,554 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:17:59,555 - INFO -   Starting training...
# 2025-06-05 15:18:01,247 - INFO -   Training completed successfully in 1.70 seconds
# 2025-06-05 15:18:01,247 - INFO -   Best iteration: 1200
# 2025-06-05 15:18:01,435 - INFO -   Model highly_regularized - RMSE: 3.803846
# 2025-06-05 15:18:01,437 - INFO -   Prediction statistics: min=-4.6022, max=75.6601, mean=2.7958
# 2025-06-05 15:18:01,437 - INFO -   ---------------------
# 2025-06-05 15:18:01,437 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:18:01,439 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:18:01,440 - INFO -   Starting training...
# 2025-06-05 15:18:03,324 - INFO -   Training completed successfully in 1.89 seconds
# 2025-06-05 15:18:03,324 - INFO -   Best iteration: 800
# 2025-06-05 15:18:03,441 - INFO -   Model fast_learner - RMSE: 3.161575
# 2025-06-05 15:18:03,441 - INFO -   Prediction statistics: min=-5.4701, max=91.4978, mean=2.7999
# 2025-06-05 15:18:03,441 - INFO -   ---------------------
# 2025-06-05 15:18:03,441 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:18:03,441 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:18:03,441 - INFO -   Starting training...
# 2025-06-05 15:18:08,658 - INFO -   Training completed successfully in 5.22 seconds
# 2025-06-05 15:18:08,658 - INFO -   Best iteration: 1800
# 2025-06-05 15:18:08,973 - INFO -   Model balanced - RMSE: 3.347182
# 2025-06-05 15:18:08,974 - INFO -   Prediction statistics: min=-4.2151, max=87.0666, mean=2.8120
# 2025-06-05 15:18:08,974 - INFO -   ---------------------
# 2025-06-05 15:18:08,976 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:18:23,397 - INFO -   Optimal weights found: 0.0000, 0.0000, 0.0000, 0.3942, 0.0000, 0.6058, 0.0000
# 2025-06-05 15:18:23,397 - INFO -   Bayesian optimization - RMSE: 3.133830
# 2025-06-05 15:18:23,397 - INFO -   Final prediction statistics: min=-4.7598, max=89.5374, mean=2.7988
# 2025-06-05 15:18:23,397 - INFO -   RMSE with equal weights: 3.302558
# 2025-06-05 15:18:23,397 - INFO -   Improvement: 5.11%
# 2025-06-05 15:18:23,397 - INFO - Fold 4 completed in 47.30 seconds
# 2025-06-05 15:18:23,397 - INFO - =====================
# 2025-06-05 15:18:23,397 - INFO - Fold 5/5 for Model_4_Data4
# 2025-06-05 15:18:23,397 - INFO - Train: 21039 samples, Validation: 5259 samples
# 2025-06-05 15:18:23,421 - INFO - y_train statistics: min=0.0000, max=119.8869, mean=2.7832
# 2025-06-05 15:18:23,422 - INFO - y_val statistics: min=0.0000, max=122.5230, mean=2.8935
# 2025-06-05 15:18:23,424 - INFO -   ---------------------
# 2025-06-05 15:18:23,424 - INFO -   Training base model 1/7 (precise)...
# 2025-06-05 15:18:23,426 - INFO -   Parameters: {
#   "n_estimators": 2000,
#   "learning_rate": 0.01,
#   "max_depth": 8,
#   "num_leaves": 31,
#   "colsample_bytree": 0.8,
#   "subsample": 0.8,
#   "reg_alpha": 0.1,
#   "reg_lambda": 0.1,
#   "min_child_weight": 10,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:18:23,428 - INFO -   Starting training...
# 2025-06-05 15:18:28,333 - INFO -   Training completed successfully in 4.91 seconds
# 2025-06-05 15:18:28,333 - INFO -   Best iteration: 2000
# 2025-06-05 15:18:28,650 - INFO -   Model precise - RMSE: 3.286778
# 2025-06-05 15:18:28,650 - INFO -   Prediction statistics: min=-3.2059, max=81.9714, mean=2.9090
# 2025-06-05 15:18:28,666 - INFO -   ---------------------
# 2025-06-05 15:18:28,666 - INFO -   Training base model 2/7 (feature_selective)...
# 2025-06-05 15:18:28,666 - INFO -   Parameters: {
#   "n_estimators": 1500,
#   "learning_rate": 0.02,
#   "max_depth": 6,
#   "colsample_bytree": 0.6,
#   "subsample": 0.9,
#   "reg_alpha": 1.0,
#   "reg_lambda": 0.1,
#   "feature_fraction": 0.7,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:18:28,668 - INFO -   Starting training...
# 2025-06-05 15:18:31,813 - INFO -   Training completed successfully in 3.15 seconds
# 2025-06-05 15:18:31,813 - INFO -   Best iteration: 1500
# 2025-06-05 15:18:32,036 - INFO -   Model feature_selective - RMSE: 3.270522
# 2025-06-05 15:18:32,036 - INFO -   Prediction statistics: min=-5.4115, max=83.3833, mean=2.8936
# 2025-06-05 15:18:32,036 - INFO -   ---------------------
# 2025-06-05 15:18:32,052 - INFO -   Training base model 3/7 (robust)...
# 2025-06-05 15:18:32,054 - INFO -   Parameters: {
#   "n_estimators": 1000,
#   "learning_rate": 0.03,
#   "max_depth": 5,
#   "colsample_bytree": 0.9,
#   "subsample": 0.7,
#   "reg_alpha": 0.5,
#   "reg_lambda": 1.0,
#   "min_data_in_leaf": 20,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:18:32,054 - INFO -   Starting training...
# 2025-06-05 15:18:34,228 - INFO -   Training completed successfully in 2.19 seconds
# 2025-06-05 15:18:34,228 - INFO -   Best iteration: 992
# 2025-06-05 15:18:34,370 - INFO -   Model robust - RMSE: 3.326356
# 2025-06-05 15:18:34,370 - INFO -   Prediction statistics: min=-6.5351, max=86.7617, mean=2.8786
# 2025-06-05 15:18:34,370 - INFO -   ---------------------
# 2025-06-05 15:18:34,370 - INFO -   Training base model 4/7 (deep_forest)...
# 2025-06-05 15:18:34,370 - INFO -   Parameters: {
#   "n_estimators": 3000,
#   "learning_rate": 0.005,
#   "max_depth": 12,
#   "num_leaves": 64,
#   "colsample_bytree": 0.75,
#   "subsample": 0.75,
#   "reg_alpha": 0.2,
#   "reg_lambda": 0.2,
#   "min_child_weight": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 150
# }
# 2025-06-05 15:18:34,370 - INFO -   Starting training...
# 2025-06-05 15:18:46,166 - INFO -   Training completed successfully in 11.80 seconds
# 2025-06-05 15:18:46,166 - INFO -   Best iteration: 3000
# 2025-06-05 15:18:47,060 - INFO -   Model deep_forest - RMSE: 3.201430
# 2025-06-05 15:18:47,060 - INFO -   Prediction statistics: min=-3.7894, max=80.9253, mean=2.8846
# 2025-06-05 15:18:47,060 - INFO -   ---------------------
# 2025-06-05 15:18:47,064 - INFO -   Training base model 5/7 (highly_regularized)...
# 2025-06-05 15:18:47,064 - INFO -   Parameters: {
#   "n_estimators": 1200,
#   "learning_rate": 0.02,
#   "max_depth": 4,
#   "num_leaves": 16,
#   "colsample_bytree": 0.7,
#   "subsample": 0.8,
#   "reg_alpha": 2.0,
#   "reg_lambda": 2.0,
#   "min_child_weight": 15,
#   "min_data_in_leaf": 25,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 100
# }
# 2025-06-05 15:18:47,064 - INFO -   Starting training...
# 2025-06-05 15:18:48,751 - INFO -   Training completed successfully in 1.69 seconds
# 2025-06-05 15:18:48,751 - INFO -   Best iteration: 1200
# 2025-06-05 15:18:48,878 - INFO -   Model highly_regularized - RMSE: 3.819072
# 2025-06-05 15:18:48,878 - INFO -   Prediction statistics: min=-4.2096, max=86.1891, mean=2.8943
# 2025-06-05 15:18:48,878 - INFO -   ---------------------
# 2025-06-05 15:18:48,878 - INFO -   Training base model 6/7 (fast_learner)...
# 2025-06-05 15:18:48,894 - INFO -   Parameters: {
#   "n_estimators": 800,
#   "learning_rate": 0.08,
#   "max_depth": 6,
#   "num_leaves": 32,
#   "colsample_bytree": 0.85,
#   "subsample": 0.85,
#   "reg_alpha": 0.3,
#   "reg_lambda": 0.3,
#   "min_child_weight": 8,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 80
# }
# 2025-06-05 15:18:48,894 - INFO -   Starting training...
# 2025-06-05 15:18:51,069 - INFO -   Training completed successfully in 2.19 seconds
# 2025-06-05 15:18:51,069 - INFO -   Best iteration: 800
# 2025-06-05 15:18:51,212 - INFO -   Model fast_learner - RMSE: 3.083503
# 2025-06-05 15:18:51,214 - INFO -   Prediction statistics: min=-5.7876, max=84.8236, mean=2.9125
# 2025-06-05 15:18:51,214 - INFO -   ---------------------
# 2025-06-05 15:18:51,214 - INFO -   Training base model 7/7 (balanced)...
# 2025-06-05 15:18:51,217 - INFO -   Parameters: {
#   "n_estimators": 1800,
#   "learning_rate": 0.015,
#   "max_depth": 7,
#   "num_leaves": 40,
#   "colsample_bytree": 0.75,
#   "subsample": 0.85,
#   "reg_alpha": 0.4,
#   "reg_lambda": 0.4,
#   "min_child_weight": 12,
#   "bagging_freq": 5,
#   "random_state": 42,
#   "objective": "rmse",
#   "metric": "rmse",
#   "verbose": -1,
#   "early_stopping_rounds": 120
# }
# 2025-06-05 15:18:51,218 - INFO -   Starting training...
# 2025-06-05 15:18:56,659 - INFO -   Training completed successfully in 5.45 seconds
# 2025-06-05 15:18:56,661 - INFO -   Best iteration: 1797
# 2025-06-05 15:18:56,950 - INFO -   Model balanced - RMSE: 3.318731
# 2025-06-05 15:18:56,950 - INFO -   Prediction statistics: min=-5.4330, max=83.2596, mean=2.8806
# 2025-06-05 15:18:56,954 - INFO -   ---------------------
# 2025-06-05 15:18:56,954 - INFO -   Searching for optimal weights with Bayesian optimization...
# 2025-06-05 15:19:10,381 - INFO -   Optimal weights found: 0.0000, 0.0000, 0.0000, 0.2038, 0.0000, 0.7962, 0.0000
# 2025-06-05 15:19:10,396 - INFO -   Bayesian optimization - RMSE: 3.074938
# 2025-06-05 15:19:10,396 - INFO -   Final prediction statistics: min=-5.3218, max=82.4106, mean=2.9068
# 2025-06-05 15:19:10,401 - INFO -   RMSE with equal weights: 3.246885
# 2025-06-05 15:19:10,401 - INFO -   Improvement: 5.30%
# 2025-06-05 15:19:10,401 - INFO - Fold 5 completed in 47.00 seconds
# 2025-06-05 15:19:10,401 - INFO - =====================
# 2025-06-05 15:19:10,401 - INFO - CV RMSE for Model_4_Data4 (with optimal weights): 3.091316 ± 0.328368
# 2025-06-05 15:19:10,401 - INFO - OOF RMSE for Model_4_Data4 (with optimal weights): 3.108708
# 2025-06-05 15:19:10,412 - INFO - OOF prediction statistics: min=-7.1682, max=96.7013, mean=2.8100
# 2025-06-05 15:19:10,412 - INFO - OOF RMSE for base model precise: 3.320064
# 2025-06-05 15:19:10,412 - INFO - OOF RMSE for base model feature_selective: 3.319384
# 2025-06-05 15:19:10,420 - INFO - OOF RMSE for base model robust: 3.372151
# 2025-06-05 15:19:10,420 - INFO - OOF RMSE for base model deep_forest: 3.260024
# 2025-06-05 15:19:10,428 - INFO - OOF RMSE for base model highly_regularized: 3.828530
# 2025-06-05 15:19:10,431 - INFO - OOF RMSE for base model fast_learner: 3.119945
# 2025-06-05 15:19:10,435 - INFO - OOF RMSE for base model balanced: 3.368692
# 2025-06-05 15:19:10,437 - INFO - Average optimal weights across all folds: 0.0572, 0.0000, 0.0000, 0.1196, 0.0000, 0.8232, 0.0000
# 2025-06-05 15:19:10,437 - INFO - Complete training finished in 230.88 seconds (3.85 minutes)
# 2025-06-05 15:19:10,437 - INFO - ========== END TRAINING Model_4_Data4 ==========
#                Model  Mean CV RMSE  Std CV RMSE  OOF RMSE
# 0     Model1 (Data1)      3.195617     0.285916  3.208342
# 1     Model2 (Data2)      2.904201     0.111232  2.906339
# 2  Model4 (Complete)      3.091316     0.328368  3.108708

# %% [markdown]
# ### Test Preparation and Predictions

# %% [markdown]
# In this section:
#
# 1. Prepares the test data by applying the same feature engineering pipeline
# 2. Generates predictions using each of the four models
# 3. Creates the final ensemble prediction with a sophisticated weighting scheme
# 4. Ensures all predictions are non-negative

# %%
# Test Preparation
logger.info("Preparing test data (SampleSubmission) + advanced features...")

# Reload sample submission to ensure we have a clean copy
ss = pd.read_csv('SampleSubmission.csv')

# Copy sample submission for predictions
forecast = ss.copy()

# Extract date and source information
forecast['Date'] = pd.to_datetime(forecast['ID'].str.extract(r'(\d{4}-\d{2}-\d{2})')[0])
forecast[['DateSplit','device','data','user']] = forecast['ID'].str.split('_',expand=True,n=3)
forecast['Source'] = forecast['device'] + '_' + forecast['data'] + '_' + forecast['user']
forecast.drop(columns=['device','data','user','DateSplit'], inplace=True, errors='ignore')

# Apply advanced feature engineering to test data
forecast = add_advanced_features(forecast, climate_df)

# Prepare test data for prediction
X_test = forecast.drop(columns=['Date','kwh','ID'], errors='ignore')


logger.info("Making predictions with all models...")

logger.info("Predictions for Model 1 (CV)...")
preds_1 = predict_with_cv_models(models1, X_test, cols1)

logger.info("Predictions for Model 2 (CV)...")
preds_2 = predict_with_cv_models(models2, X_test, cols2)

logger.info("Predictions for Model 3 (direct training)...")
preds_3 = predict_with_cv_models(models3, X_test, cols3)

logger.info("Predictions for Model 4 (CV)...")
preds_4 = predict_with_cv_models(models4, X_test, cols4)

# Create multi-level ensemble with optimized weights
w1, w2, w3, w4 = 0.85, 0.025, 0.025, 0.1  # Weights adjusted according to data segmentation, w1 is high is because data1 is close to close to the testing period
logger.info(f"Creating final ensemble with weights: {w1}, {w2}, {w3}, {w4}")

# Multi-level ensemble formula
final_preds = 0.3*preds_1 + 0.65*(0.7*preds_1 + 0.2*(0.8*preds_1 + 0.1*(w1*preds_1 + w2*preds_2 + w3*preds_3 + w4*preds_4) + 0.1*preds_4) + 0.1*preds_4) + 0.05*preds_4

# Ensure all predictions are non-negative
final_preds = np.maximum(0, final_preds)

# Create submission file
submission = ss.copy()
submission['kwh'] = final_preds
submission.to_csv('output/final_submission.csv', index=False)
logger.info(f"✅ Submission file generated with ensemble weights: {w1}, {w2}, {w3}, {w4}")

# Plot distribution of final predictions
plt.figure(figsize=(12, 6))
plt.hist(final_preds, bins=50, alpha=0.7, color='blue')
plt.title('Distribution of Final Predictions')
plt.xlabel('Predicted kWh')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# 2025-06-05 15:25:49,731 - INFO - Preparing test data (SampleSubmission) + advanced features...
# 2025-06-05 15:25:49,770 - INFO - Adding advanced features...
# 2025-06-05 15:25:51,154 - INFO - Making predictions with all models...
# 2025-06-05 15:25:51,154 - INFO - Predictions for Model 1 (CV)...
# 2025-06-05 15:25:51,154 - INFO - Starting prediction with 5 models on 6014 samples...
# 2025-06-05 15:25:51,161 - INFO - Using 56/56 available columns for prediction
# 2025-06-05 15:25:51,165 - INFO - Detection of stacked models with optimal weights...
# 2025-06-05 15:25:51,166 - INFO -   Prediction for fold 1/5...
# 2025-06-05 15:25:51,168 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:25:51,483 - INFO -     Prediction statistics for model 1: min=-8.7989, max=88.9261, mean=3.8182
# 2025-06-05 15:25:51,483 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:25:51,727 - INFO -     Prediction statistics for model 2: min=-7.0762, max=88.6284, mean=3.7024
# 2025-06-05 15:25:51,727 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:25:51,888 - INFO -     Prediction statistics for model 3: min=-12.2123, max=86.7550, mean=3.6418
# 2025-06-05 15:25:51,889 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:25:52,863 - INFO -     Prediction statistics for model 4: min=-8.7880, max=90.7653, mean=3.5684
# 2025-06-05 15:25:52,863 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:25:53,001 - INFO -     Prediction statistics for model 5: min=-4.7824, max=77.1811, mean=3.6868
# 2025-06-05 15:25:53,001 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:25:53,066 - INFO -     Prediction statistics for model 6: min=-11.9384, max=89.4952, mean=3.5162
# 2025-06-05 15:25:53,067 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:25:53,394 - INFO -     Prediction statistics for model 7: min=-9.4178, max=85.4327, mean=3.4481
# 2025-06-05 15:25:53,396 - INFO -     Applying optimal weights: 0.0000, 0.3031, 0.0000, 0.4195, 0.0000, 0.2774, 0.0000
# 2025-06-05 15:25:53,397 - INFO -     Statistics of weighted predictions: min=-9.1432, max=89.7653, mean=3.5945
# 2025-06-05 15:25:53,397 - INFO -   Prediction for fold 2/5...
# 2025-06-05 15:25:53,399 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:25:53,701 - INFO -     Prediction statistics for model 1: min=-5.7336, max=90.2846, mean=3.5740
# 2025-06-05 15:25:53,701 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:25:53,968 - INFO -     Prediction statistics for model 2: min=-6.6762, max=87.9862, mean=3.5313
# 2025-06-05 15:25:53,968 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:25:54,132 - INFO -     Prediction statistics for model 3: min=-10.2050, max=87.2159, mean=3.6610
# 2025-06-05 15:25:54,132 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:25:55,197 - INFO -     Prediction statistics for model 4: min=-6.2748, max=87.5302, mean=3.3902
# 2025-06-05 15:25:55,199 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:25:55,324 - INFO -     Prediction statistics for model 5: min=-8.0127, max=78.0224, mean=3.6747
# 2025-06-05 15:25:55,325 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:25:55,371 - INFO -     Prediction statistics for model 6: min=-9.6786, max=88.2689, mean=3.4306
# 2025-06-05 15:25:55,372 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:25:55,720 - INFO -     Prediction statistics for model 7: min=-10.5739, max=86.0056, mean=3.5244
# 2025-06-05 15:25:55,721 - INFO -     Applying optimal weights: 0.3749, 0.0000, 0.0000, 0.2437, 0.0000, 0.3814, 0.0000
# 2025-06-05 15:25:55,722 - INFO -     Statistics of weighted predictions: min=-7.3700, max=88.8445, mean=3.4745
# 2025-06-05 15:25:55,723 - INFO -   Prediction for fold 3/5...
# 2025-06-05 15:25:55,723 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:25:56,129 - INFO -     Prediction statistics for model 1: min=-10.8150, max=86.4804, mean=3.8339
# 2025-06-05 15:25:56,131 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:25:56,379 - INFO -     Prediction statistics for model 2: min=-7.3385, max=88.4512, mean=3.8502
# 2025-06-05 15:25:56,380 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:25:56,525 - INFO -     Prediction statistics for model 3: min=-12.2861, max=90.7302, mean=3.7750
# 2025-06-05 15:25:56,527 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:25:57,634 - INFO -     Prediction statistics for model 4: min=-8.0744, max=87.8700, mean=3.7054
# 2025-06-05 15:25:57,634 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:25:57,770 - INFO -     Prediction statistics for model 5: min=-6.7241, max=76.6954, mean=3.4413
# 2025-06-05 15:25:57,772 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:25:57,901 - INFO -     Prediction statistics for model 6: min=-10.0271, max=90.5318, mean=3.5379
# 2025-06-05 15:25:57,901 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:25:58,280 - INFO -     Prediction statistics for model 7: min=-9.5986, max=86.5194, mean=3.5815
# 2025-06-05 15:25:58,282 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.2719, 0.0000, 0.7281, 0.0000
# 2025-06-05 15:25:58,284 - INFO -     Statistics of weighted predictions: min=-9.4961, max=89.8080, mean=3.5834
# 2025-06-05 15:25:58,284 - INFO -   Prediction for fold 4/5...
# 2025-06-05 15:25:58,286 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:25:58,655 - INFO -     Prediction statistics for model 1: min=-5.2555, max=88.4295, mean=3.7423
# 2025-06-05 15:25:58,655 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:25:58,928 - INFO -     Prediction statistics for model 2: min=-7.3028, max=87.6986, mean=3.7855
# 2025-06-05 15:25:58,930 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:25:58,985 - INFO -     Prediction statistics for model 3: min=-4.2665, max=84.2335, mean=3.6720
# 2025-06-05 15:25:58,985 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:25:59,986 - INFO -     Prediction statistics for model 4: min=-5.9887, max=86.7929, mean=3.5965
# 2025-06-05 15:25:59,986 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:00,117 - INFO -     Prediction statistics for model 5: min=-7.4549, max=85.2211, mean=3.7095
# 2025-06-05 15:26:00,117 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:00,210 - INFO -     Prediction statistics for model 6: min=-9.8542, max=90.1184, mean=3.4126
# 2025-06-05 15:26:00,212 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:00,613 - INFO -     Prediction statistics for model 7: min=-7.4901, max=83.6155, mean=3.5964
# 2025-06-05 15:26:00,615 - INFO -     Applying optimal weights: 0.0000, 0.2867, 0.0000, 0.0000, 0.0000, 0.7133, 0.0000
# 2025-06-05 15:26:00,616 - INFO -     Statistics of weighted predictions: min=-8.5999, max=89.4246, mean=3.5196
# 2025-06-05 15:26:00,616 - INFO -   Prediction for fold 5/5...
# 2025-06-05 15:26:00,617 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:01,000 - INFO -     Prediction statistics for model 1: min=-6.3775, max=88.0601, mean=3.7081
# 2025-06-05 15:26:01,001 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:01,237 - INFO -     Prediction statistics for model 2: min=-9.3992, max=82.9161, mean=3.5878
# 2025-06-05 15:26:01,237 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:01,276 - INFO -     Prediction statistics for model 3: min=-11.1085, max=79.1884, mean=3.6634
# 2025-06-05 15:26:01,278 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:01,485 - INFO -     Prediction statistics for model 4: min=-3.5030, max=76.9980, mean=3.5462
# 2025-06-05 15:26:01,485 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:01,618 - INFO -     Prediction statistics for model 5: min=-6.6352, max=78.8192, mean=3.5819
# 2025-06-05 15:26:01,618 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:01,718 - INFO -     Prediction statistics for model 6: min=-16.8373, max=93.1278, mean=3.4630
# 2025-06-05 15:26:01,718 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:02,135 - INFO -     Prediction statistics for model 7: min=-6.9939, max=81.0150, mean=3.3761
# 2025-06-05 15:26:02,135 - INFO -     Applying optimal weights: 0.0000, 0.6831, 0.0000, 0.0000, 0.0000, 0.0576, 0.2593
# 2025-06-05 15:26:02,135 - INFO -     Statistics of weighted predictions: min=-9.2038, max=82.7312, mean=3.5257
# 2025-06-05 15:26:02,135 - INFO - Final predictions (average of 5 folds): min=-8.7626, max=87.2785, mean=3.5396
# 2025-06-05 15:26:02,145 - INFO - Predictions for Model 2 (CV)...
# 2025-06-05 15:26:02,145 - INFO - Starting prediction with 5 models on 6014 samples...
# 2025-06-05 15:26:02,151 - INFO - Using 56/56 available columns for prediction
# 2025-06-05 15:26:02,151 - INFO - Detection of stacked models with optimal weights...
# 2025-06-05 15:26:02,151 - INFO -   Prediction for fold 1/5...
# 2025-06-05 15:26:02,151 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:02,567 - INFO -     Prediction statistics for model 1: min=-2.9997, max=31.4418, mean=1.6176
# 2025-06-05 15:26:02,567 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:02,855 - INFO -     Prediction statistics for model 2: min=-2.9107, max=29.0067, mean=1.5491
# 2025-06-05 15:26:02,857 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:03,020 - INFO -     Prediction statistics for model 3: min=-1.6152, max=30.0241, mean=1.3973
# 2025-06-05 15:26:03,020 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:04,309 - INFO -     Prediction statistics for model 4: min=-2.8749, max=29.2242, mean=1.5336
# 2025-06-05 15:26:04,309 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:04,432 - INFO -     Prediction statistics for model 5: min=-1.3255, max=35.4471, mean=1.6039
# 2025-06-05 15:26:04,432 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:04,552 - INFO -     Prediction statistics for model 6: min=-3.9089, max=30.7825, mean=1.3960
# 2025-06-05 15:26:04,553 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:04,954 - INFO -     Prediction statistics for model 7: min=-1.5641, max=30.0992, mean=1.4690
# 2025-06-05 15:26:04,954 - INFO -     Applying optimal weights: 0.0000, 0.1292, 0.0000, 0.0000, 0.0000, 0.8708, 0.0000
# 2025-06-05 15:26:04,954 - INFO -     Statistics of weighted predictions: min=-3.5363, max=30.5288, mean=1.4157
# 2025-06-05 15:26:04,954 - INFO -   Prediction for fold 2/5...
# 2025-06-05 15:26:04,954 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:05,339 - INFO -     Prediction statistics for model 1: min=-2.2127, max=33.8503, mean=1.3735
# 2025-06-05 15:26:05,341 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:05,600 - INFO -     Prediction statistics for model 2: min=-3.3814, max=31.2875, mean=1.2645
# 2025-06-05 15:26:05,600 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:05,736 - INFO -     Prediction statistics for model 3: min=-2.1740, max=33.8786, mean=1.1546
# 2025-06-05 15:26:05,736 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:06,930 - INFO -     Prediction statistics for model 4: min=-2.8862, max=33.6180, mean=1.3172
# 2025-06-05 15:26:06,932 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:07,062 - INFO -     Prediction statistics for model 5: min=-1.8547, max=28.9554, mean=1.3483
# 2025-06-05 15:26:07,064 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:07,205 - INFO -     Prediction statistics for model 6: min=-4.6386, max=34.3719, mean=1.2236
# 2025-06-05 15:26:07,206 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:07,620 - INFO -     Prediction statistics for model 7: min=-2.7183, max=29.9882, mean=1.3885
# 2025-06-05 15:26:07,622 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7414, 0.2586
# 2025-06-05 15:26:07,624 - INFO -     Statistics of weighted predictions: min=-3.8520, max=32.7150, mean=1.2663
# 2025-06-05 15:26:07,624 - INFO -   Prediction for fold 3/5...
# 2025-06-05 15:26:07,626 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:08,084 - INFO -     Prediction statistics for model 1: min=-2.1161, max=34.8500, mean=1.5331
# 2025-06-05 15:26:08,086 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:08,350 - INFO -     Prediction statistics for model 2: min=-2.6500, max=34.4839, mean=1.4789
# 2025-06-05 15:26:08,350 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:08,443 - INFO -     Prediction statistics for model 3: min=-2.6957, max=38.5214, mean=1.4411
# 2025-06-05 15:26:08,443 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:09,683 - INFO -     Prediction statistics for model 4: min=-1.9876, max=32.0960, mean=1.5446
# 2025-06-05 15:26:09,683 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:09,883 - INFO -     Prediction statistics for model 5: min=-1.9979, max=35.5968, mean=1.4691
# 2025-06-05 15:26:09,883 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:09,950 - INFO -     Prediction statistics for model 6: min=-3.0966, max=35.1989, mean=1.3998
# 2025-06-05 15:26:09,950 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:10,312 - INFO -     Prediction statistics for model 7: min=-2.2655, max=28.6181, mean=1.4502
# 2025-06-05 15:26:10,315 - INFO -     Applying optimal weights: 0.0000, 0.4716, 0.0000, 0.0000, 0.0000, 0.5284, 0.0000
# 2025-06-05 15:26:10,317 - INFO -     Statistics of weighted predictions: min=-1.7805, max=33.8662, mean=1.4371
# 2025-06-05 15:26:10,317 - INFO -   Prediction for fold 4/5...
# 2025-06-05 15:26:10,320 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:10,878 - INFO -     Prediction statistics for model 1: min=-2.3767, max=33.8238, mean=1.4583
# 2025-06-05 15:26:10,880 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:11,225 - INFO -     Prediction statistics for model 2: min=-2.0890, max=32.6052, mean=1.4486
# 2025-06-05 15:26:11,225 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:11,383 - INFO -     Prediction statistics for model 3: min=-2.4000, max=36.9523, mean=1.3490
# 2025-06-05 15:26:11,384 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:12,940 - INFO -     Prediction statistics for model 4: min=-4.2831, max=37.5340, mean=1.5096
# 2025-06-05 15:26:12,940 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:13,082 - INFO -     Prediction statistics for model 5: min=-1.6888, max=30.2344, mean=1.3324
# 2025-06-05 15:26:13,083 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:13,216 - INFO -     Prediction statistics for model 6: min=-2.7290, max=33.6183, mean=1.4315
# 2025-06-05 15:26:13,216 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:13,630 - INFO -     Prediction statistics for model 7: min=-1.6328, max=33.3884, mean=1.5901
# 2025-06-05 15:26:13,632 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.0547, 0.0000, 0.9453, 0.0000
# 2025-06-05 15:26:13,633 - INFO -     Statistics of weighted predictions: min=-2.5787, max=33.8325, mean=1.4358
# 2025-06-05 15:26:13,634 - INFO -   Prediction for fold 5/5...
# 2025-06-05 15:26:13,634 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:13,983 - INFO -     Prediction statistics for model 1: min=-1.9622, max=34.9963, mean=1.6211
# 2025-06-05 15:26:13,985 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:14,100 - INFO -     Prediction statistics for model 2: min=-1.8960, max=37.1053, mean=1.5732
# 2025-06-05 15:26:14,100 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:14,233 - INFO -     Prediction statistics for model 3: min=-1.8772, max=36.3980, mean=1.5292
# 2025-06-05 15:26:14,233 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:15,438 - INFO -     Prediction statistics for model 4: min=-1.5332, max=35.0696, mean=1.6907
# 2025-06-05 15:26:15,440 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:15,558 - INFO -     Prediction statistics for model 5: min=-1.9311, max=33.2082, mean=1.4760
# 2025-06-05 15:26:15,558 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:15,649 - INFO -     Prediction statistics for model 6: min=-2.1984, max=31.9318, mean=1.6518
# 2025-06-05 15:26:15,651 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:15,998 - INFO -     Prediction statistics for model 7: min=-2.2168, max=30.1126, mean=1.5403
# 2025-06-05 15:26:16,000 - INFO -     Applying optimal weights: 0.1364, 0.0000, 0.0000, 0.0000, 0.1131, 0.6637, 0.0868
# 2025-06-05 15:26:16,002 - INFO -     Statistics of weighted predictions: min=-1.5112, max=31.6117, mean=1.6181
# 2025-06-05 15:26:16,002 - INFO - Final predictions (average of 5 folds): min=-1.6408, max=27.8789, mean=1.4346
# 2025-06-05 15:26:16,004 - INFO - Predictions for Model 3 (direct training)...
# 2025-06-05 15:26:16,004 - INFO - Starting prediction with 1 models on 6014 samples...
# 2025-06-05 15:26:16,009 - INFO - Using 50/50 available columns for prediction
# 2025-06-05 15:26:16,014 - INFO - Using simple models...
# 2025-06-05 15:26:16,014 - INFO -   Prediction with model 1/1...
# 2025-06-05 15:26:16,022 - INFO -   Prediction statistics for model 1: min=0.0006, max=0.0006, mean=0.0006
# 2025-06-05 15:26:16,022 - INFO - Final predictions (average of 1 models): min=0.0006, max=0.0006, mean=0.0006
# 2025-06-05 15:26:16,022 - INFO - Predictions for Model 4 (CV)...
# 2025-06-05 15:26:16,022 - INFO - Starting prediction with 5 models on 6014 samples...
# 2025-06-05 15:26:16,028 - INFO - Using 56/56 available columns for prediction
# 2025-06-05 15:26:16,033 - INFO - Detection of stacked models with optimal weights...
# 2025-06-05 15:26:16,033 - INFO -   Prediction for fold 1/5...
# 2025-06-05 15:26:16,033 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:16,347 - INFO -     Prediction statistics for model 1: min=-2.3578, max=79.8034, mean=2.6069
# 2025-06-05 15:26:16,349 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:16,674 - INFO -     Prediction statistics for model 2: min=-2.2879, max=78.1461, mean=2.5948
# 2025-06-05 15:26:16,674 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:16,828 - INFO -     Prediction statistics for model 3: min=-2.5532, max=82.2085, mean=2.8242
# 2025-06-05 15:26:16,828 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:17,815 - INFO -     Prediction statistics for model 4: min=-2.8083, max=80.8083, mean=2.6278
# 2025-06-05 15:26:17,816 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:17,983 - INFO -     Prediction statistics for model 5: min=-1.7711, max=74.8781, mean=2.9347
# 2025-06-05 15:26:17,983 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:18,116 - INFO -     Prediction statistics for model 6: min=-4.2400, max=78.2864, mean=2.5815
# 2025-06-05 15:26:18,116 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:18,484 - INFO -     Prediction statistics for model 7: min=-3.1632, max=77.6880, mean=2.6226
# 2025-06-05 15:26:18,484 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000
# 2025-06-05 15:26:18,486 - INFO -     Statistics of weighted predictions: min=-4.2400, max=78.2864, mean=2.5815
# 2025-06-05 15:26:18,488 - INFO -   Prediction for fold 2/5...
# 2025-06-05 15:26:18,488 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:18,793 - INFO -     Prediction statistics for model 1: min=-2.3201, max=79.3755, mean=2.9773
# 2025-06-05 15:26:18,793 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:19,072 - INFO -     Prediction statistics for model 2: min=-2.7975, max=79.8800, mean=2.9727
# 2025-06-05 15:26:19,072 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:19,249 - INFO -     Prediction statistics for model 3: min=-3.3648, max=86.1326, mean=3.0884
# 2025-06-05 15:26:19,249 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:20,204 - INFO -     Prediction statistics for model 4: min=-3.0193, max=79.3232, mean=2.9644
# 2025-06-05 15:26:20,206 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:20,352 - INFO -     Prediction statistics for model 5: min=-1.4996, max=74.1905, mean=3.0007
# 2025-06-05 15:26:20,366 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:20,525 - INFO -     Prediction statistics for model 6: min=-4.9716, max=79.2670, mean=3.0034
# 2025-06-05 15:26:20,527 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:20,911 - INFO -     Prediction statistics for model 7: min=-2.2524, max=77.8696, mean=2.8281
# 2025-06-05 15:26:20,913 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000
# 2025-06-05 15:26:20,915 - INFO -     Statistics of weighted predictions: min=-4.9716, max=79.2670, mean=3.0034
# 2025-06-05 15:26:20,916 - INFO -   Prediction for fold 3/5...
# 2025-06-05 15:26:20,916 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:21,252 - INFO -     Prediction statistics for model 1: min=-1.7327, max=75.4379, mean=2.7504
# 2025-06-05 15:26:21,254 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:21,536 - INFO -     Prediction statistics for model 2: min=-3.4891, max=80.1101, mean=2.6960
# 2025-06-05 15:26:21,538 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:21,692 - INFO -     Prediction statistics for model 3: min=-3.4802, max=75.5279, mean=2.7458
# 2025-06-05 15:26:21,693 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:22,611 - INFO -     Prediction statistics for model 4: min=-1.4445, max=74.3490, mean=2.7564
# 2025-06-05 15:26:22,611 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:22,733 - INFO -     Prediction statistics for model 5: min=-1.6511, max=69.5175, mean=3.0550
# 2025-06-05 15:26:22,733 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:22,881 - INFO -     Prediction statistics for model 6: min=-7.2892, max=72.4317, mean=2.8050
# 2025-06-05 15:26:22,882 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:23,200 - INFO -     Prediction statistics for model 7: min=-2.9181, max=73.1803, mean=2.5094
# 2025-06-05 15:26:23,200 - INFO -     Applying optimal weights: 0.2858, 0.0000, 0.0000, 0.0000, 0.0000, 0.7142, 0.0000
# 2025-06-05 15:26:23,215 - INFO -     Statistics of weighted predictions: min=-4.7635, max=72.6980, mean=2.7894
# 2025-06-05 15:26:23,216 - INFO -   Prediction for fold 4/5...
# 2025-06-05 15:26:23,216 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:23,581 - INFO -     Prediction statistics for model 1: min=-2.5157, max=77.5715, mean=2.7066
# 2025-06-05 15:26:23,583 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:23,867 - INFO -     Prediction statistics for model 2: min=-3.3932, max=75.5941, mean=2.6930
# 2025-06-05 15:26:23,867 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:24,033 - INFO -     Prediction statistics for model 3: min=-4.4496, max=77.1035, mean=2.8631
# 2025-06-05 15:26:24,033 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:24,966 - INFO -     Prediction statistics for model 4: min=-2.0645, max=79.0648, mean=2.6398
# 2025-06-05 15:26:24,966 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:25,116 - INFO -     Prediction statistics for model 5: min=-1.2615, max=70.5450, mean=2.9301
# 2025-06-05 15:26:25,116 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:25,266 - INFO -     Prediction statistics for model 6: min=-5.7703, max=82.6637, mean=2.8466
# 2025-06-05 15:26:25,266 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:25,647 - INFO -     Prediction statistics for model 7: min=-3.3339, max=74.8909, mean=2.6064
# 2025-06-05 15:26:25,647 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.3942, 0.0000, 0.6058, 0.0000
# 2025-06-05 15:26:25,647 - INFO -     Statistics of weighted predictions: min=-3.8959, max=81.2451, mean=2.7651
# 2025-06-05 15:26:25,647 - INFO -   Prediction for fold 5/5...
# 2025-06-05 15:26:25,647 - INFO -     Prediction with base model 1/7...
# 2025-06-05 15:26:25,971 - INFO -     Prediction statistics for model 1: min=-3.5389, max=82.1655, mean=2.8780
# 2025-06-05 15:26:25,971 - INFO -     Prediction with base model 2/7...
# 2025-06-05 15:26:26,258 - INFO -     Prediction statistics for model 2: min=-3.3967, max=82.0282, mean=2.7391
# 2025-06-05 15:26:26,258 - INFO -     Prediction with base model 3/7...
# 2025-06-05 15:26:26,419 - INFO -     Prediction statistics for model 3: min=-4.2370, max=85.8170, mean=2.6723
# 2025-06-05 15:26:26,419 - INFO -     Prediction with base model 4/7...
# 2025-06-05 15:26:27,481 - INFO -     Prediction statistics for model 4: min=-6.2213, max=83.6704, mean=2.5012
# 2025-06-05 15:26:27,482 - INFO -     Prediction with base model 5/7...
# 2025-06-05 15:26:27,670 - INFO -     Prediction statistics for model 5: min=-1.9891, max=80.5185, mean=2.9779
# 2025-06-05 15:26:27,670 - INFO -     Prediction with base model 6/7...
# 2025-06-05 15:26:27,850 - INFO -     Prediction statistics for model 6: min=-6.1569, max=87.2878, mean=2.9412
# 2025-06-05 15:26:27,852 - INFO -     Prediction with base model 7/7...
# 2025-06-05 15:26:28,300 - INFO -     Prediction statistics for model 7: min=-4.3232, max=81.9829, mean=2.5334
# 2025-06-05 15:26:28,302 - INFO -     Applying optimal weights: 0.0000, 0.0000, 0.0000, 0.2038, 0.0000, 0.7962, 0.0000
# 2025-06-05 15:26:28,304 - INFO -     Statistics of weighted predictions: min=-5.6932, max=86.5504, mean=2.8515
# 2025-06-05 15:26:28,304 - INFO - Final predictions (average of 5 folds): min=-2.3520, max=77.9259, mean=2.7982
# 2025-06-05 15:26:28,307 - INFO - Creating final ensemble with weights: 0.85, 0.025, 0.025, 0.1
# 2025-06-05 15:26:28,335 - INFO - ✅ Submission file generated with ensemble weights: 0.85, 0.025, 0.025, 0.1

# %%
# Visualizations and Analyses

logger.info("Generating visualization of predictions...")

# 1) Prediction Statistics
stats_data = {
    'Model': ['Model1(Data1)', 'Model2(Data2)', 'Model3(Data3)', 'Model4(Data4)', f'Ensemble({w1},{w2},{w3},{w4})'],
    'Min': [preds_1.min(), preds_2.min(), preds_3.min(), preds_4.min(), final_preds.min()],
    'Max': [preds_1.max(), preds_2.max(), preds_3.max(), preds_4.max(), final_preds.max()],
    'Mean': [preds_1.mean(), preds_2.mean(), preds_3.mean(), preds_4.mean(), final_preds.mean()],
    'Median': [np.median(preds_1), np.median(preds_2), np.median(preds_3), np.median(preds_4), np.median(final_preds)],
    'Std Dev': [preds_1.std(), preds_2.std(), preds_3.std(), preds_4.std(), final_preds.std()],
}
stats_df = pd.DataFrame(stats_data)
display(stats_df)
stats_df.to_csv('output/predictions_stats_advanced.csv', index=False)

# 2) Histograms
plt.figure(figsize=(16, 10))
plt.subplot(2, 3, 1)
plt.hist(preds_1, bins=50, alpha=0.7, color='blue')
plt.title("Predictions Model1(Data1)")
plt.xlabel("kWh")
plt.ylabel("Frequency")

plt.subplot(2, 3, 2)
plt.hist(preds_2, bins=50, alpha=0.7, color='green')
plt.title("Predictions Model2(Data2)")
plt.xlabel("kWh")
plt.ylabel("Frequency")

plt.subplot(2, 3, 3)
plt.hist(preds_3, bins=50, alpha=0.7, color='red')
plt.title("Predictions Model3(Data3)")
plt.xlabel("kWh")
plt.ylabel("Frequency")

plt.subplot(2, 3, 4)
plt.hist(preds_4, bins=50, alpha=0.7, color='yellow')
plt.title("Predictions Model4(Data4)")
plt.xlabel("kWh")
plt.ylabel("Frequency")

plt.subplot(2, 3, 5)
plt.hist(final_preds, bins=50, alpha=0.7, color='purple')
plt.title(f"Ensemble ({w1},{w2},{w3},{w4})")
plt.xlabel("kWh")
plt.ylabel("Frequency")

plt.tight_layout()
plt.savefig("output/histograms_advanced_models.png")
logger.info("✅ Histograms saved to output/histograms_advanced_models.png")

# 3) Temporal Evolutions
logger.info("Plotting temporal evolution...")
dates = forecast['Date']
sorted_idx = np.argsort(dates)
sorted_dates = dates.iloc[sorted_idx]

sorted_1 = preds_1[sorted_idx]
sorted_2 = preds_2[sorted_idx]
sorted_3 = preds_3[sorted_idx]
sorted_4 = preds_4[sorted_idx]
sorted_final = final_preds[sorted_idx]

plt.figure(figsize=(16, 8))
plt.plot(sorted_dates, sorted_1, 'b-', label='Model1(Data1)', alpha=0.4)
plt.plot(sorted_dates, sorted_2, 'g-', label='Model2(Data2)', alpha=0.4)
plt.plot(sorted_dates, sorted_3, 'r-', label='Model3(Data3)', alpha=0.4)
plt.plot(sorted_dates, sorted_4, 'orange', label='Model4(Data4)', alpha=0.4)
plt.plot(sorted_dates, sorted_final, 'k-', label=f'Ensemble({w1},{w2},{w3}, {w4})', linewidth=2)
plt.title("Temporal evolution of predictions - Sorted by date")
plt.xlabel("Date")
plt.ylabel("Predicted kWh")
plt.legend()
plt.grid(True, alpha=0.3)

import matplotlib.dates as mdates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.savefig("output/timeline_predictions_advanced.png")
logger.info("✅ Temporal evolution saved to output/timeline_predictions_advanced.png")

logger.info("✅ Analysis and visualizations complete")
# Out:
# 2025-06-05 15:29:55,040 - INFO - Generating visualization of predictions...
#                             Model       Min        Max      Mean    Median  \
# 0                   Model1(Data1) -8.762618  87.278480  3.539556  0.447424
# 1                   Model2(Data2) -1.640823  27.878903  1.434596  0.210760
# 2                   Model3(Data3)  0.000612   0.000612  0.000612  0.000612
# 3                   Model4(Data4) -2.352032  77.925877  2.798183  0.125894
# 4  Ensemble(0.85,0.025,0.025,0.1)  0.000000  86.014959  3.507812  0.403257
#
#     Std Dev
# 0  8.939829
# 1  3.385360
# 2  0.000000
# 3  6.938493
# 4  8.595405
# 2025-06-05 15:29:56,230 - INFO - ✅ Histograms saved to output/histograms_advanced_models.png
# 2025-06-05 15:29:56,230 - INFO - Plotting temporal evolution...
# 2025-06-05 15:29:56,692 - INFO - ✅ Temporal evolution saved to output/timeline_predictions_advanced.png
# 2025-06-05 15:29:56,693 - INFO - ✅ Analysis and visualizations complete

# %% [markdown]
# ## 8. Conclusion and Performance Summary

# %% [markdown]
# This solution demonstrates how smart data segmentation and powerful ensemble algorithms may produce excellent energy-consumption estimates even under extreme weather conditions.

# %% [markdown]
# #### Key Performance Metrics
# **Private Leaderboard RMSE**: 4.312706649

# %% [markdown]
# #### Strengths of the Approach
#
# ***1. Targeted Data Segmentation***: By partitioning the data according to seasonal consumption patterns, each model learned the behaviors most relevant to its assigned date range.
#
# ***2. Tailored Feature Engineering***: Custom features reflecting Pakistan’s unique climate and cultural variables helped capture crucial consumption drivers.
#
# ***3. Ensemble Diversity***: Multiple LightGBM models with diverse hyperparameters minimized overfitting and enriched the final blended predictions.
#
# ***4. Bayesian Optimization***: Automatically finding the optimal ensemble weights provided additional performance gain by ensuring the most effective model blend.

# %% [markdown]
# #### Future Directions
# ***1. Device-Specific Modeling***: Training specialized models for different device types or user profiles may further boost accuracy.
#
# ***2. Time-Series Integration & Expanded Modeling***: Leveraging additional forecasting approaches—like ARIMA or other specialized time-series frameworks, advanced gradient boosting variants, or deeper feature engineering and feature selection—could uncover more nuanced temporal patterns.
#
# ***3. Zero-Consumption Handling***: Investigating more nuanced approaches for prolonged zero-usage segments might clarify low-demand periods.
#
# ***4. Extreme Weather Modeling***: Dedicated routines for severe temperature or weather shocks could further strengthen predictive robustness.
#
# This winning solution highlights the power of domain-informed feature engineering and methodical ensembling, delivering robust, high-accuracy predictions for real-world energy consumption scenarios.
